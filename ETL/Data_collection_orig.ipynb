# %%
## Dependencies

import pandas as pd
import pathlib as path

import requests
import json
from pprint import pprint

import numpy as np

from io import StringIO

# to read the ZIP file
import requests
import zipfile
import io

# %% [markdown]
# # (1) create DF for countries
#
# #### information will be used to merge or generate vizualisations
# source : https://api.worldbank.org/v2/country?format=json

# %%
## retrieve all the countries from world bank API

### generate DF Countries

page = 1   ## there are 6 pages in the json file
data = []
url_countries = 'https://api.worldbank.org/v2/country?format=json'

for page in range(1,7):
    response = requests.get(f"{url_countries}&page={page}")
    json_data = response.json()
    
    # Add the data from the current page
    data.extend(json_data[1])  
    
## create DF and select columns

countries_wb_df = pd.DataFrame(data)
countries_wb_df['region'] = countries_wb_df['region'].apply(lambda x: x['value'])
countries_wb_df = countries_wb_df[['id', 'iso2Code', 'name', 'region','capitalCity', 'longitude', 'latitude']]
countries_wb_df = countries_wb_df.rename(columns={
                                                    'name':'country',
                                                    'id':'iso3Code'
                                                    })


regions = (countries_wb_df['region'] != "Aggregates")
countries_wb_df = countries_wb_df[regions]


countries_wb_df.head()
# Out:
#   iso3Code iso2Code      country                      region  \
# 0      ABW       AW        Aruba  Latin America & Caribbean
# 2      AFG       AF  Afghanistan                  South Asia
# 5      AGO       AO       Angola         Sub-Saharan Africa
# 6      ALB       AL      Albania       Europe & Central Asia
# 7      AND       AD      Andorra       Europe & Central Asia
#
#         capitalCity longitude  latitude
# 0        Oranjestad  -70.0167   12.5167
# 2             Kabul   69.1761   34.5228
# 5            Luanda    13.242  -8.81155
# 6            Tirane   19.8172   41.3317
# 7  Andorra la Vella    1.5218   42.5075

# %%
# countries_wb_df = countries_wb_df.set_index("index")

# %%
### Export to csv file in output

countries_wb_df.to_csv('../Output/countries_UN_referential.csv', index=False)

# %% [markdown]
# # (2) collect immigration data

# %% [markdown]
# ##### Data source from IRCC web site
# this file is updated on a monthly basis by IRCC
#
# https://www.ircc.canada.ca/opendata-donneesouvertes/data/ODP-PR-Citz.csv
# from
# https://ouvert.canada.ca/data/fr/dataset/f7e5498e-0ad8-4417-85c9-9b8aff9b9eda/resource/5f5fa9ca-b621-4dac-91d1-25654a25735c

# %%
### import and read csv file from web page

path_imm = 'https://www.ircc.canada.ca/opendata-donneesouvertes/data/ODP-PR-Citz.csv'
imm_df = pd.read_csv(path_imm, delimiter='\t')

# imm_df.to_csv('../Output/immigration_raw_data.csv')
imm_df.head(5)
# Out:
#    EN_YEAR EN_QUARTER EN_MONTH  FR_ANNEÉ FR_TRIMESTRE FR_MOIS  \
# 0     2015         Q1      Feb      2015           T1    fév.
# 1     2015         Q1      Feb      2015           T1    fév.
# 2     2015         Q1      Feb      2015           T1    fév.
# 3     2015         Q1      Feb      2015           T1    fév.
# 4     2015         Q1      Feb      2015           T1    fév.
#
#   EN_COUNTRY_OF_CITIZENSHIP FR_PAYS_DE_CITOYENNETÉ TOTAL
# 0               Afghanistan            Afghanistan   125
# 1                   Albania                Albanie    25
# 2                   Algeria                Algérie   125
# 3       Antigua and Barbuda     Antigua-et-Barbuda     5
# 4                 Argentina              Argentine    15

# %%
# drop useless columns

imm_df = imm_df.drop(columns=['FR_ANNEÉ','FR_TRIMESTRE','FR_MOIS','FR_PAYS_DE_CITOYENNETÉ'])
imm_df.head(5)
# Out:
#    EN_YEAR EN_QUARTER EN_MONTH EN_COUNTRY_OF_CITIZENSHIP TOTAL
# 0     2015         Q1      Feb               Afghanistan   125
# 1     2015         Q1      Feb                   Albania    25
# 2     2015         Q1      Feb                   Algeria   125
# 3     2015         Q1      Feb       Antigua and Barbuda     5
# 4     2015         Q1      Feb                 Argentina    15

# %%
# check empty values with 1 example raw 42

print(imm_df.loc[42,])
# Out:
# EN_YEAR                          2015
# EN_QUARTER                         Q1
# EN_MONTH                          Feb
# EN_COUNTRY_OF_CITIZENSHIP    Dominica
# TOTAL                              --
# Name: 42, dtype: object

# %%
imm_clean_df = imm_df.copy()

# %%
# convert Total to numeric

imm_clean_df['TOTAL'] = pd.to_numeric(imm_clean_df['TOTAL'], errors='coerce')

# replace NAN with 0 and change data type

imm_clean_df = imm_clean_df.fillna({'TOTAL': 0})
imm_clean_df = imm_clean_df.astype({'TOTAL': 'int64'})
print(imm_clean_df.loc[42,])
# Out:
# EN_YEAR                          2015
# EN_QUARTER                         Q1
# EN_MONTH                          Feb
# EN_COUNTRY_OF_CITIZENSHIP    Dominica
# TOTAL                               0
# Name: 42, dtype: object

# %%
# check that total is numeric _ integer

imm_clean_df.dtypes
# Out:
# EN_YEAR                       int64
# EN_QUARTER                   object
# EN_MONTH                     object
# EN_COUNTRY_OF_CITIZENSHIP    object
# TOTAL                         int64
# dtype: object

# %%
# rename columns 

imm_clean_df = imm_clean_df.rename(columns={
                                            'EN_YEAR'            :           'year' ,
                                            'EN_QUARTER'         :          'quarter' , 
                                            'EN_MONTH'           :          'month_str' ,
                                            'EN_COUNTRY_OF_CITIZENSHIP' :   'country' ,  
                                            'TOTAL'              :           'immigration_flow'
                                            })
imm_clean_df.dtypes
# Out:
# year                 int64
# quarter             object
# month_str           object
# country             object
# immigration_flow     int64
# dtype: object

# %% [markdown]
# #### 2.1 the steps below are needed to match the name of the countries between this DF and countries_df
#
# example : IRCC name is 'Bahama Islands, The'
# for world bank :   'Bahamas, The' ,
# because we will use country as column to merge, we need to harmonize the countries names
#
# 1st we identify the countries names that mismatch
# then we change them
# the preparation of the mapping is done manually

# %%
# to identify the countries names that mismatch between IRCC and World bank

countries_wb = pd.DataFrame(countries_wb_df['country'].unique() , columns=['country'])
countries_ircc = pd.DataFrame(imm_clean_df['country'].unique(),  columns=['country'])

# Add a source column to indicate the origin
countries_wb['source'] = 'countries_wb'
countries_ircc['source'] = 'countries_ircc'

# Concatenate the two DataFrames
all_countries = pd.concat([countries_wb, countries_ircc], ignore_index=True)

# Find non-corresponding values
non_corresponding_values = all_countries.groupby('country').filter(lambda x: len(x) == 1)

# Display the non-corresponding values with their origin
print(non_corresponding_values)
# non_corresponding_values.to_csv('Output/non_corresponding_countries.csv')
# Out:
#             country          source
# 0             Aruba    countries_wb
# 8    American Samoa    countries_wb
# 15            Benin    countries_wb
# 16     Burkina Faso    countries_wb
# 20     Bahamas, The    countries_wb
# ..              ...             ...
# 423        Holy See  countries_ircc
# 424          Azores  countries_ircc
# 427      Guadeloupe  countries_ircc
# 431         Reunion  countries_ircc
# 432    Sint-Maarten  countries_ircc
#
# [158 rows x 2 columns]

# %%
# Change countries name to match to th United Nations standard

imm_clean_df['country'] = imm_clean_df['country'].replace({
                            
                                    'Azores'  :  'Canada' ,
                                    'Bahama Islands, The'  :  'Bahamas, The' ,
                                    'Benin, Republic of'  :  'Benin' ,
                                    'Bosnia-Herzegovina'  :  'Bosnia and Herzegovina' ,
                                    'Botswana, Republic of'  :  'Botswana' ,
                                    'Brunei'  :  'Brunei Darussalam' ,
                                    'Burkina-Faso'  :  'Burkina Faso' ,
                                    'Cameroon, Federal Republic of'  :  'Cameroon' ,
                                    'Cape Verde Islands'  :  'Cabo Verde' ,
                                    'Chad, Republic of'  :  'Chad' ,
                                    "China, People's Republic of"  :  'China' ,
                                    'Congo, Democratic Republic of the'  :  'Congo, Dem. Rep.' ,
                                    "Congo, People's Republic of the"  :  'Congo, Rep.' ,
                                    'Country not stated'  :  'Canada' ,
                                    'Czech Republic'  :  'Czechia' ,
                                    'Djibouti, Republic of'  :  'Djibouti' ,
                                    'East Timor, Democratic Republic of'  :  'Timor-Leste' ,
                                    'Egypt'  :  'Egypt, Arab Rep.' ,
                                    'Equatorial Guinea, Republic of'  :  'Equatorial Guinea' ,
                                    'Gabon Republic'  :  'Gabon' ,
                                    'Gambia'  :  'Gambia, The' ,
                                    'Guadeloupe'  :  'France' ,
                                    'Guinea, Republic of'  :  'Guinea' ,
                                    'Holy See'  :  'Canada' ,
                                    'Hong Kong SAR'  :  'Hong Kong SAR, China' ,
                                    'Indonesia, Republic of'  :  'Indonesia' ,
                                    'Iran'  :  'Iran, Islamic Rep.' ,
                                    'Ireland, Republic of'  :  'Ireland' ,
                                    'Ivory Coast, Republic of'  :  "Cote d'Ivoire" ,
                                    "Korea, People's Democratic Republic of"  :  "Korea, Dem. People's Rep." ,
                                    'Korea, Republic of'  :  'Korea, Rep.' ,
                                    'Kosovo, Republic of'  :  'Kosovo' ,
                                    'Kyrgyzstan'  :  'Kyrgyz Republic' ,
                                    'Laos'  :  'Lao PDR' ,
                                    'Macau SAR'  :  'Macao SAR, China' ,
                                    'Macedonia'  :  'North Macedonia' ,
                                    'Maldives, Republic of'  :  'Maldives' ,
                                    'Mali, Republic of'  :  'Mali' ,
                                    'Marshall Islands, Republic of the'  :  'Marshall Islands' ,
                                    'Micronesia, Federated States of'  :  'Canada' ,
                                    "Mongolia, People's Republic of"  :  'Mongolia' ,
                                    'Montenegro, Republic of'  :  'Montenegro' ,
                                    'Myanmar (Burma)'  :  'Myanmar' ,
                                    'Netherlands Antilles, The'  :  'Canada' ,
                                    'Netherlands, The'  :  'Netherlands' ,
                                    'Nevis'  :  'Canada' ,
                                    'Niger, Republic of the'  :  'Niger' ,
                                    'Northern Mariana Islands, Commonwealth of the'  :  'Northern Mariana Islands' ,
                                    'Other'  :  'Canada' ,
                                    'Palau, Republic of'  :  'Palau' ,
                                    'Palestinian Authority (Gaza/West Bank)'  :  'West Bank and Gaza' ,
                                    'Panama, Republic of'  :  'Panama' ,
                                    'Reunion'  :  'France' ,
                                    'Russia'  :  'Russian Federation' ,
                                    'Samoa, American'  :  'Samoa' ,
                                    'Samoa, Independent State of'  :  'American Samoa' ,
                                    'Serbia, Republic of'  :  'Serbia' ,
                                    'Sint-Maarten'  :  'Sint Maarten (Dutch part)' ,
                                    'Somalia, Democratic Republic of'  :  'Somalia' ,
                                    'South Africa, Republic of'  :  'South Africa' ,
                                    'South Sudan, Republic of'  :  'South Sudan' ,
                                    'St. Kitts-Nevis'  :  'Canada' ,
                                    'Stateless'  :  'Canada' ,
                                    'Sudan, Democratic Republic of'  :  'Sudan' ,
                                    'Surinam'  :  'Suriname' ,
                                    'Swaziland'  :  'Somalia' ,
                                    'Syria'  :  'Syrian Arab Republic' ,
                                    'Taiwan'  :  'China' ,
                                    'Tanzania, United Republic of'  :  'Tanzania' ,
                                    'Togo, Republic of'  :  'Togo' ,
                                    'Trinidad and Tobago, Republic of'  :  'Trinidad and Tobago' ,
                                    'Turkey'  :  'Turkiye' ,
                                    'United Kingdom and Overseas Territories'  :  'United Kingdom' ,
                                    'United States of America'  :  'United States' ,
                                    'Venezuela'  :  'Venezuela, RB' ,
                                    'Vietnam'  :  'Viet Nam' ,
                                    'Virgin Islands, British'  :  'British Virgin Islands' ,
                                    'Western Sahara'  :  'Canada' ,
                                    'Yemen'  :  'Yemen, Rep.' ,


                                     })

# %%
# chech if the modification is effiscinet : we should have only countries_wb source

countries_wb = pd.DataFrame(countries_wb_df['country'].unique() , columns=['country'])
countries_ircc = pd.DataFrame(imm_clean_df['country'].unique(),  columns=['country'])

# Add a source column to indicate the origin
countries_wb['source'] = 'countries_wb'
countries_ircc['source'] = 'countries_ircc'

# Concatenate the two DataFrames
all_countries = pd.concat([countries_wb, countries_ircc], ignore_index=True)

# Find non-corresponding values
non_corresponding_values = all_countries.groupby('country').filter(lambda x: len(x) == 1)

# Display the non-corresponding values with their origin
print(non_corresponding_values)  ## you must have only countries_wb source
# Out:
#                       country        source
# 0                       Aruba  countries_wb
# 34            Channel Islands  countries_wb
# 47             Cayman Islands  countries_wb
# 65              Faroe Islands  countries_wb
# 66      Micronesia, Fed. Sts.  countries_wb
# 71                  Gibraltar  countries_wb
# 78                  Greenland  countries_wb
# 80                       Guam  countries_wb
# 88                Isle of Man  countries_wb
# 104       St. Kitts and Nevis  countries_wb
# 119  St. Martin (French part)  countries_wb
# 183                  Eswatini  countries_wb
# 208     Virgin Islands (U.S.)  countries_wb

# %% [markdown]
# #### 2.2 other cleaning steps

# %%
# add months with numerical values
 ## check that there is no strange value 

months_str = imm_clean_df['month_str'].unique()
months_str
# Out:
# array(['Feb', 'Jan', 'Mar', 'Apr', 'Jun', 'May', 'Aug', 'Jul', 'Sep',
#        'Dec', 'Nov', 'Oct'], dtype=object)

# %%
# use of Mapping to add integers to month abbreviations

month_mapping = {
    'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6,
    'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12
}

# Map month abbreviations to integers using the dictionary
imm_clean_df['month_int'] = imm_clean_df['month_str'].map(month_mapping)

imm_clean_df.head(5)
# Out:
#    year quarter month_str              country  immigration_flow  month_int
# 0  2015      Q1       Feb          Afghanistan               125          2
# 1  2015      Q1       Feb              Albania                25          2
# 2  2015      Q1       Feb              Algeria               125          2
# 3  2015      Q1       Feb  Antigua and Barbuda                 5          2
# 4  2015      Q1       Feb            Argentina                15          2

# %%
# organize columns

imm_clean_df = imm_clean_df[['country', 'year', 'month_str', 
                            'month_int','quarter', 'immigration_flow']]
imm_clean_df.head(5)
# Out:
#                country  year month_str  month_int quarter  immigration_flow
# 0          Afghanistan  2015       Feb          2      Q1               125
# 1              Albania  2015       Feb          2      Q1                25
# 2              Algeria  2015       Feb          2      Q1               125
# 3  Antigua and Barbuda  2015       Feb          2      Q1                 5
# 4            Argentina  2015       Feb          2      Q1                15

# %%
# this step is usefull to set a key during the DB building

imm_new_df = imm_clean_df.reset_index()
imm_new_df.head(5)
# Out:
#    index              country  year month_str  month_int quarter  \
# 0      0          Afghanistan  2015       Feb          2      Q1
# 1      1              Albania  2015       Feb          2      Q1
# 2      2              Algeria  2015       Feb          2      Q1
# 3      3  Antigua and Barbuda  2015       Feb          2      Q1
# 4      4            Argentina  2015       Feb          2      Q1
#
#    immigration_flow
# 0               125
# 1                25
# 2               125
# 3                 5
# 4                15

# %%
# export to CSV

imm_new_df.to_csv('../Output/immigrants_by_country_monthly.csv', index=False)

# %% [markdown]
# # (3) Extract macro economic data
# #### from world bank API
# source : https://api.worldbank.org/v2/country/DZA/indicator/NY.GDP.PCAP.KD?date=2015:2024&format=json
#
# to request the API, we need to customize
# - the country using the iso3code : fo example Afghanistan = AFG
# - define the indicator : there are more than 1480 indicators, a selection is done (manually or using an additional csv file filled manually to be filtred)
# - 1st year and last year
#
# because we need all the countries, the number of end points will be : number of countries x number of indicators x number of years

# %%
# the API uses the iso3Code code of the country (example PAK for pakistan, AFG for Afghanistan)
# we need to identify the needed countries from from our immigration_df and retrieve these iso3Code from countries_df

countries_request = pd.merge(imm_new_df, countries_wb_df, left_on='country', right_on='country')
countries_request
# Out:
#        index              country  year month_str  month_int quarter  \
# 0          0          Afghanistan  2015       Feb          2      Q1
# 1          1              Albania  2015       Feb          2      Q1
# 2          2              Algeria  2015       Feb          2      Q1
# 3          3  Antigua and Barbuda  2015       Feb          2      Q1
# 4          4            Argentina  2015       Feb          2      Q1
# ...      ...                  ...   ...       ...        ...     ...
# 20036  20036        Venezuela, RB  2024       Oct         10      Q4
# 20037  20037             Viet Nam  2024       Oct         10      Q4
# 20038  20038          Yemen, Rep.  2024       Oct         10      Q4
# 20039  20039               Zambia  2024       Oct         10      Q4
# 20040  20040             Zimbabwe  2024       Oct         10      Q4
#
#        immigration_flow iso3Code iso2Code                      region  \
# 0                   125      AFG       AF                  South Asia
# 1                    25      ALB       AL       Europe & Central Asia
# 2                   125      DZA       DZ  Middle East & North Africa
# 3                     5      ATG       AG  Latin America & Caribbean
# 4                    15      ARG       AR  Latin America & Caribbean
# ...                 ...      ...      ...                         ...
# 20036               200      VEN       VE  Latin America & Caribbean
# 20037               365      VNM       VN         East Asia & Pacific
# 20038                35      YEM       YE  Middle East & North Africa
# 20039                 0      ZMB       ZM         Sub-Saharan Africa
# 20040                35      ZWE       ZW         Sub-Saharan Africa
#
#         capitalCity longitude  latitude
# 0             Kabul   69.1761   34.5228
# 1            Tirane   19.8172   41.3317
# 2           Algiers   3.05097   36.7397
# 3      Saint John's  -61.8456   17.1175
# 4      Buenos Aires  -58.4173  -34.6118
# ...             ...       ...       ...
# 20036       Caracas  -69.8371   9.08165
# 20037         Hanoi   105.825   21.0069
# 20038        Sana'a   44.2075    15.352
# 20039        Lusaka   28.2937  -15.3982
# 20040        Harare   31.0672  -17.8312
#
# [20041 rows x 13 columns]

# %%
# extrac the needed iso3code in a list to be used to iterate

country_list = countries_request['iso3Code'].unique().tolist()
country_list[0:5]
# Out:
# ['AFG', 'ALB', 'DZA', 'ATG', 'ARG']

# %%
# this line is just to check that we are connected to the API : O TEST before loop

link_pop = f'https://api.worldbank.org/v2/country/DZA/indicator/NY.GDP.PCAP.KD?date=2015:2024&format=json'
response_pop = requests.get(link_pop).json()

pprint(response_pop)
# Out:
# [{'lastupdated': '2025-01-28',
#   'page': 1,
#   'pages': 1,
#   'per_page': 50,
#   'sourceid': '2',
#   'total': 9},
#  [{'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2023',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4660.40545686886},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2022',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4544.46688059647},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2021',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4456.74687641147},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2020',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4363.68533766912},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2019',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4672.66408682198},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2018',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4717.00358853556},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2017',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4742.90075536604},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2016',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4768.73140080218},
#   {'country': {'id': 'DZ', 'value': 'Algeria'},
#    'countryiso3code': 'DZA',
#    'date': '2015',
#    'decimal': 1,
#    'indicator': {'id': 'NY.GDP.PCAP.KD',
#                  'value': 'GDP per capita (constant 2015 US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 4685.05902729002}]]

# %%
# this cell is used to check our code before to launch the loop 
# TO TEST before loop


link_pop = f'https://api.worldbank.org/v2/country/DZA/indicator/NY.GDP.PCAP.KD?date=2015:2024&format=json'
response_pop = requests.get(link_pop).json()

# pprint(response_pop)

pop_list = []
for item in response_pop[1]:  # Assuming response_pop[1] is a list of dictionaries
    pop_list.append({
        'iso3Code': item['countryiso3code'],
        'iso2Code': item['country']['id'],
        'Country': item['country']['value'],              
        'year': item['date'],
        'indicator': item['indicator']['value'],
        'value': item['value']
    })

pop_list
# Out:
# [{'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2023',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4660.40545686886},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2022',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4544.46688059647},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2021',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4456.74687641147},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2020',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4363.68533766912},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2019',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4672.66408682198},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2018',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4717.00358853556},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2017',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4742.90075536604},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2016',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4768.73140080218},
#  {'iso3Code': 'DZA',
#   'iso2Code': 'DZ',
#   'Country': 'Algeria',
#   'year': '2015',
#   'indicator': 'GDP per capita (constant 2015 US$)',
#   'value': 4685.05902729002}]

# %%
# DEFINE THE VARIABLES : INDICATORS, TIME PERIOD

# define 1st and last year for the loop

year_min = 2015
year_max = 2024
# years_list = [x for x in range(year_min, year_max +1)]   # COULD BE USED BUT NOT IN THE CURRENT CODE

# %%
# DEFINE THE VARIABLES : INDICATORS, TIME PERIOD
# create the list of indicators

indicators = [
                'AG.LND.AGRI.ZS'  ,
                'AG.LND.PRCP.MM'  ,
                'ER.H2O.FWST.ZS'  ,
                'CC.EST'  ,
                'IC.REG.COST.PC.ZS'  ,
                'IC.BUS.DFRN.XQ'  ,
                'IC.FRM.BNKS.ZS'  ,
                'IC.REG.DURS'  ,
                'SL.UEM.ADVN.ZS'  ,
                'SL.UEM.BASC.ZS'  ,
                'SL.UEM.INTM.ZS'  ,
                'SL.UEM.TOTL.ZS'  ,
                'EG.CFT.ACCS.ZS'  ,
                'EG.ELC.ACCS.ZS'  ,
                'SP.DYN.CBRT.IN'  ,
                'SP.DYN.CDRT.IN'  ,
                'SP.DYN.TFRT.IN'  ,
                'HD.HCI.OVRL'  ,
                'SP.DYN.LE00.IN'  ,
                'EN.POP.DNST'  ,
                'SP.POP.GROW'  ,
                'EN.POP.EL5M.ZS'  ,
                'EN.POP.SLUM.UR.ZS'  ,
                'SP.POP.TOTL'  ,
                'SI.POV.DDAY'  ,
                'SI.POV.LMIC'  ,
                'SI.POV.UMIC'  ,
                'SI.POV.NAHC'  ,
                'SH.ALC.PCAP.LI'  ,
                'MS.MIL.TOTL.TF.ZS'  ,
                'GC.DOD.TOTL.GD.ZS'  ,
                'FP.CPI.TOTL'  ,
                'BN.CAB.XOKA.GD.ZS'  ,
                'SH.XPD.CHEX.GD.ZS'  ,
                'DT.TDS.DPPF.XP.ZS'  ,
                'NY.GDP.MKTP.KD.ZG'  ,
                'NY.GDP.PCAP.KD'  ,
                'NY.GDP.PCAP.PP.KD'  ,
                'NE.CON.GOVT.ZS'  ,
                'NY.GNP.PCAP.KD'  ,
                'SE.XPD.TOTL.GD.ZS'  ,
                'NV.IND.TOTL.ZS'  ,
                'FP.CPI.TOTL.ZG'  ,
                'MS.MIL.XPND.GD.ZS'  ,
                'DT.TDS.DECT.EX.ZS'  ,
                'DT.TDS.DECT.GN.ZS'  ,
                
                ]

print(f'Number of indicators is : {len(indicators)}')
# Out:
# Number of indicators is : 46

# %%
# lOOP to extract data from API : 20 indicators (between 15 and 18 minutes), 46 indicators (between 50 and 60 minutes)

# this code will loop through all the listed countries and the needed indicators to generate a list

print(f"start code")
print('---------------------------')

macro_eco_data_list = []

# the end point is defined by (i) country (II) indicator (III) year start and year end
        # => we need to create 1 end point of each country / indicator

for i in country_list :

    for j in indicators :

        print(f"--------------------------")
        print(f"country {i} indicator {j}")

        try:

            # define the end point by country (from list I) and indicator (from list J)

            link_pop = f'https://api.worldbank.org/v2/country/{i}/indicator/{j}?date={year_min}:{year_max}&format=json'
            response_pop = requests.get(link_pop).json()

            # loop through the response_pop (list) to extract the value for each year in the serie 

            for item in response_pop[1]:  
                macro_eco_data_list.append({
                    'iso3Code': item['countryiso3code'],
                    'iso2Code': item['country']['id'],
                    'country': item['country']['value'],              
                    'year': item['date'],
                    'indicator': item['indicator']['value'],
                    'value': item['value']
                })
        except:   
            print(f"country {i} indicator {j}....... not found")
# Out:
# start code
# ---------------------------
# --------------------------
# country AFG indicator AG.LND.AGRI.ZS
# --------------------------
# country AFG indicator AG.LND.PRCP.MM
# --------------------------
# country AFG indicator ER.H2O.FWST.ZS
# --------------------------
# country AFG indicator CC.EST
# --------------------------
# country AFG indicator IC.REG.COST.PC.ZS
# --------------------------
# country AFG indicator IC.BUS.DFRN.XQ
# --------------------------
# country AFG indicator IC.FRM.BNKS.ZS
# --------------------------
# country AFG indicator IC.REG.DURS
# --------------------------
# country AFG indicator SL.UEM.ADVN.ZS
# --------------------------
# country AFG indicator SL.UEM.BASC.ZS
# --------------------------
# country AFG indicator SL.UEM.INTM.ZS
# --------------------------
# country AFG indicator SL.UEM.TOTL.ZS
# --------------------------
# country AFG indicator EG.CFT.ACCS.ZS
# --------------------------
# country AFG indicator EG.ELC.ACCS.ZS
# --------------------------
# country AFG indicator SP.DYN.CBRT.IN
# --------------------------
# country AFG indicator SP.DYN.CDRT.IN
# --------------------------
# country AFG indicator SP.DYN.TFRT.IN
# --------------------------
# country AFG indicator HD.HCI.OVRL
# --------------------------
# country AFG indicator SP.DYN.LE00.IN
# --------------------------
# country AFG indicator EN.POP.DNST
# --------------------------
# country AFG indicator SP.POP.GROW
# --------------------------
# country AFG indicator EN.POP.EL5M.ZS
# --------------------------
# country AFG indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country AFG indicator SP.POP.TOTL
# --------------------------
# country AFG indicator SI.POV.DDAY
# --------------------------
# country AFG indicator SI.POV.LMIC
# --------------------------
# country AFG indicator SI.POV.UMIC
# --------------------------
# country AFG indicator SI.POV.NAHC
# --------------------------
# country AFG indicator SH.ALC.PCAP.LI
# --------------------------
# country AFG indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country AFG indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country AFG indicator FP.CPI.TOTL
# --------------------------
# country AFG indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country AFG indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country AFG indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country AFG indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country AFG indicator NY.GDP.PCAP.KD
# --------------------------
# country AFG indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country AFG indicator NE.CON.GOVT.ZS
# --------------------------
# country AFG indicator NY.GNP.PCAP.KD
# --------------------------
# country AFG indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country AFG indicator NV.IND.TOTL.ZS
# --------------------------
# country AFG indicator FP.CPI.TOTL.ZG
# --------------------------
# country AFG indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country AFG indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country AFG indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country ALB indicator AG.LND.AGRI.ZS
# --------------------------
# country ALB indicator AG.LND.PRCP.MM
# --------------------------
# country ALB indicator ER.H2O.FWST.ZS
# --------------------------
# country ALB indicator CC.EST
# --------------------------
# country ALB indicator IC.REG.COST.PC.ZS
# --------------------------
# country ALB indicator IC.BUS.DFRN.XQ
# --------------------------
# country ALB indicator IC.FRM.BNKS.ZS
# --------------------------
# country ALB indicator IC.REG.DURS
# --------------------------
# country ALB indicator SL.UEM.ADVN.ZS
# --------------------------
# country ALB indicator SL.UEM.BASC.ZS
# --------------------------
# country ALB indicator SL.UEM.INTM.ZS
# --------------------------
# country ALB indicator SL.UEM.TOTL.ZS
# --------------------------
# country ALB indicator EG.CFT.ACCS.ZS
# --------------------------
# country ALB indicator EG.ELC.ACCS.ZS
# --------------------------
# country ALB indicator SP.DYN.CBRT.IN
# --------------------------
# country ALB indicator SP.DYN.CDRT.IN
# --------------------------
# country ALB indicator SP.DYN.TFRT.IN
# --------------------------
# country ALB indicator HD.HCI.OVRL
# --------------------------
# country ALB indicator SP.DYN.LE00.IN
# --------------------------
# country ALB indicator EN.POP.DNST
# --------------------------
# country ALB indicator SP.POP.GROW
# --------------------------
# country ALB indicator EN.POP.EL5M.ZS
# --------------------------
# country ALB indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country ALB indicator SP.POP.TOTL
# --------------------------
# country ALB indicator SI.POV.DDAY
# --------------------------
# country ALB indicator SI.POV.LMIC
# --------------------------
# country ALB indicator SI.POV.UMIC
# --------------------------
# country ALB indicator SI.POV.NAHC
# --------------------------
# country ALB indicator SH.ALC.PCAP.LI
# --------------------------
# country ALB indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country ALB indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country ALB indicator FP.CPI.TOTL
# --------------------------
# country ALB indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country ALB indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country ALB indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country ALB indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country ALB indicator NY.GDP.PCAP.KD
# --------------------------
# country ALB indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country ALB indicator NE.CON.GOVT.ZS
# --------------------------
# country ALB indicator NY.GNP.PCAP.KD
# --------------------------
# country ALB indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country ALB indicator NV.IND.TOTL.ZS
# --------------------------
# country ALB indicator FP.CPI.TOTL.ZG
# --------------------------
# country ALB indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country ALB indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country ALB indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country DZA indicator AG.LND.AGRI.ZS
# --------------------------
# country DZA indicator AG.LND.PRCP.MM
# --------------------------
# country DZA indicator ER.H2O.FWST.ZS
# --------------------------
# country DZA indicator CC.EST
# --------------------------
# country DZA indicator IC.REG.COST.PC.ZS
# --------------------------
# country DZA indicator IC.BUS.DFRN.XQ
# --------------------------
# country DZA indicator IC.FRM.BNKS.ZS
# --------------------------
# country DZA indicator IC.REG.DURS
# --------------------------
# country DZA indicator SL.UEM.ADVN.ZS
# --------------------------
# country DZA indicator SL.UEM.BASC.ZS
# --------------------------
# country DZA indicator SL.UEM.INTM.ZS
# --------------------------
# country DZA indicator SL.UEM.TOTL.ZS
# --------------------------
# country DZA indicator EG.CFT.ACCS.ZS
# --------------------------
# country DZA indicator EG.ELC.ACCS.ZS
# --------------------------
# country DZA indicator SP.DYN.CBRT.IN
# --------------------------
# country DZA indicator SP.DYN.CDRT.IN
# --------------------------
# country DZA indicator SP.DYN.TFRT.IN
# --------------------------
# country DZA indicator HD.HCI.OVRL
# --------------------------
# country DZA indicator SP.DYN.LE00.IN
# --------------------------
# country DZA indicator EN.POP.DNST
# --------------------------
# country DZA indicator SP.POP.GROW
# --------------------------
# country DZA indicator EN.POP.EL5M.ZS
# --------------------------
# country DZA indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country DZA indicator SP.POP.TOTL
# --------------------------
# country DZA indicator SI.POV.DDAY
# --------------------------
# country DZA indicator SI.POV.LMIC
# --------------------------
# country DZA indicator SI.POV.UMIC
# --------------------------
# country DZA indicator SI.POV.NAHC
# --------------------------
# country DZA indicator SH.ALC.PCAP.LI
# --------------------------
# country DZA indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country DZA indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country DZA indicator FP.CPI.TOTL
# --------------------------
# country DZA indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country DZA indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country DZA indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country DZA indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country DZA indicator NY.GDP.PCAP.KD
# --------------------------
# country DZA indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country DZA indicator NE.CON.GOVT.ZS
# --------------------------
# country DZA indicator NY.GNP.PCAP.KD
# --------------------------
# country DZA indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country DZA indicator NV.IND.TOTL.ZS
# --------------------------
# country DZA indicator FP.CPI.TOTL.ZG
# --------------------------
# country DZA indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country DZA indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country DZA indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country ATG indicator AG.LND.AGRI.ZS
# --------------------------
# country ATG indicator AG.LND.PRCP.MM
# --------------------------
# country ATG indicator ER.H2O.FWST.ZS
# --------------------------
# country ATG indicator CC.EST
# --------------------------
# country ATG indicator IC.REG.COST.PC.ZS
# --------------------------
# country ATG indicator IC.BUS.DFRN.XQ
# --------------------------
# country ATG indicator IC.FRM.BNKS.ZS
# --------------------------
# country ATG indicator IC.REG.DURS
# --------------------------
# country ATG indicator SL.UEM.ADVN.ZS
# --------------------------
# country ATG indicator SL.UEM.BASC.ZS
# --------------------------
# country ATG indicator SL.UEM.INTM.ZS
# --------------------------
# country ATG indicator SL.UEM.TOTL.ZS
# --------------------------
# country ATG indicator EG.CFT.ACCS.ZS
# --------------------------
# country ATG indicator EG.ELC.ACCS.ZS
# --------------------------
# country ATG indicator SP.DYN.CBRT.IN
# --------------------------
# country ATG indicator SP.DYN.CDRT.IN
# --------------------------
# country ATG indicator SP.DYN.TFRT.IN
# --------------------------
# country ATG indicator HD.HCI.OVRL
# --------------------------
# country ATG indicator SP.DYN.LE00.IN
# --------------------------
# country ATG indicator EN.POP.DNST
# --------------------------
# country ATG indicator SP.POP.GROW
# --------------------------
# country ATG indicator EN.POP.EL5M.ZS
# --------------------------
# country ATG indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country ATG indicator SP.POP.TOTL
# --------------------------
# country ATG indicator SI.POV.DDAY
# --------------------------
# country ATG indicator SI.POV.LMIC
# --------------------------
# country ATG indicator SI.POV.UMIC
# --------------------------
# country ATG indicator SI.POV.NAHC
# --------------------------
# country ATG indicator SH.ALC.PCAP.LI
# --------------------------
# country ATG indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country ATG indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country ATG indicator FP.CPI.TOTL
# --------------------------
# country ATG indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country ATG indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country ATG indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country ATG indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country ATG indicator NY.GDP.PCAP.KD
# --------------------------
# country ATG indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country ATG indicator NE.CON.GOVT.ZS
# --------------------------
# country ATG indicator NY.GNP.PCAP.KD
# --------------------------
# country ATG indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country ATG indicator NV.IND.TOTL.ZS
# --------------------------
# country ATG indicator FP.CPI.TOTL.ZG
# --------------------------
# country ATG indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country ATG indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country ATG indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country ARG indicator AG.LND.AGRI.ZS
# --------------------------
# country ARG indicator AG.LND.PRCP.MM
# --------------------------
# country ARG indicator ER.H2O.FWST.ZS
# --------------------------
# country ARG indicator CC.EST
# --------------------------
# country ARG indicator IC.REG.COST.PC.ZS
# --------------------------
# country ARG indicator IC.BUS.DFRN.XQ
# --------------------------
# country ARG indicator IC.FRM.BNKS.ZS
# --------------------------
# country ARG indicator IC.REG.DURS
# --------------------------
# country ARG indicator SL.UEM.ADVN.ZS
# --------------------------
# country ARG indicator SL.UEM.BASC.ZS
# --------------------------
# country ARG indicator SL.UEM.INTM.ZS
# --------------------------
# country ARG indicator SL.UEM.TOTL.ZS
# --------------------------
# country ARG indicator EG.CFT.ACCS.ZS
# --------------------------
# country ARG indicator EG.ELC.ACCS.ZS
# --------------------------
# country ARG indicator SP.DYN.CBRT.IN
# --------------------------
# country ARG indicator SP.DYN.CDRT.IN
# --------------------------
# country ARG indicator SP.DYN.TFRT.IN
# --------------------------
# country ARG indicator HD.HCI.OVRL
# --------------------------
# country ARG indicator SP.DYN.LE00.IN
# --------------------------
# country ARG indicator EN.POP.DNST
# --------------------------
# country ARG indicator SP.POP.GROW
# --------------------------
# country ARG indicator EN.POP.EL5M.ZS
# --------------------------
# country ARG indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country ARG indicator SP.POP.TOTL
# --------------------------
# country ARG indicator SI.POV.DDAY
# --------------------------
# country ARG indicator SI.POV.LMIC
# --------------------------
# country ARG indicator SI.POV.UMIC
# --------------------------
# country ARG indicator SI.POV.NAHC
# --------------------------
# country ARG indicator SH.ALC.PCAP.LI
# --------------------------
# country ARG indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country ARG indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country ARG indicator FP.CPI.TOTL
# --------------------------
# country ARG indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country ARG indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country ARG indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country ARG indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country ARG indicator NY.GDP.PCAP.KD
# --------------------------
# country ARG indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country ARG indicator NE.CON.GOVT.ZS
# --------------------------
# country ARG indicator NY.GNP.PCAP.KD
# --------------------------
# country ARG indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country ARG indicator NV.IND.TOTL.ZS
# --------------------------
# country ARG indicator FP.CPI.TOTL.ZG
# --------------------------
# country ARG indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country ARG indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country ARG indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country ARM indicator AG.LND.AGRI.ZS
# --------------------------
# country ARM indicator AG.LND.PRCP.MM
# --------------------------
# country ARM indicator ER.H2O.FWST.ZS
# --------------------------
# country ARM indicator CC.EST
# --------------------------
# country ARM indicator IC.REG.COST.PC.ZS
# --------------------------
# country ARM indicator IC.BUS.DFRN.XQ
# --------------------------
# country ARM indicator IC.FRM.BNKS.ZS
# --------------------------
# country ARM indicator IC.REG.DURS
# --------------------------
# country ARM indicator SL.UEM.ADVN.ZS
# --------------------------
# country ARM indicator SL.UEM.BASC.ZS
# --------------------------
# country ARM indicator SL.UEM.INTM.ZS
# --------------------------
# country ARM indicator SL.UEM.TOTL.ZS
# --------------------------
# country ARM indicator EG.CFT.ACCS.ZS
# --------------------------
# country ARM indicator EG.ELC.ACCS.ZS
# --------------------------
# country ARM indicator SP.DYN.CBRT.IN
# --------------------------
# country ARM indicator SP.DYN.CDRT.IN
# --------------------------
# country ARM indicator SP.DYN.TFRT.IN
# --------------------------
# country ARM indicator HD.HCI.OVRL
# --------------------------
# country ARM indicator SP.DYN.LE00.IN
# --------------------------
# country ARM indicator EN.POP.DNST
# --------------------------
# country ARM indicator SP.POP.GROW
# --------------------------
# country ARM indicator EN.POP.EL5M.ZS
# --------------------------
# country ARM indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country ARM indicator SP.POP.TOTL
# --------------------------
# country ARM indicator SI.POV.DDAY
# --------------------------
# country ARM indicator SI.POV.LMIC
# --------------------------
# country ARM indicator SI.POV.UMIC
# --------------------------
# country ARM indicator SI.POV.NAHC
# --------------------------
# country ARM indicator SH.ALC.PCAP.LI
# --------------------------
# country ARM indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country ARM indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country ARM indicator FP.CPI.TOTL
# --------------------------
# country ARM indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country ARM indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country ARM indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country ARM indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country ARM indicator NY.GDP.PCAP.KD
# --------------------------
# country ARM indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country ARM indicator NE.CON.GOVT.ZS
# --------------------------
# country ARM indicator NY.GNP.PCAP.KD
# --------------------------
# country ARM indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country ARM indicator NV.IND.TOTL.ZS
# --------------------------
# country ARM indicator FP.CPI.TOTL.ZG
# --------------------------
# country ARM indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country ARM indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country ARM indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country AUS indicator AG.LND.AGRI.ZS
# --------------------------
# country AUS indicator AG.LND.PRCP.MM
# --------------------------
# country AUS indicator ER.H2O.FWST.ZS
# --------------------------
# country AUS indicator CC.EST
# --------------------------
# country AUS indicator IC.REG.COST.PC.ZS
# --------------------------
# country AUS indicator IC.BUS.DFRN.XQ
# --------------------------
# country AUS indicator IC.FRM.BNKS.ZS
# --------------------------
# country AUS indicator IC.REG.DURS
# --------------------------
# country AUS indicator SL.UEM.ADVN.ZS
# --------------------------
# country AUS indicator SL.UEM.BASC.ZS
# --------------------------
# country AUS indicator SL.UEM.INTM.ZS
# --------------------------
# country AUS indicator SL.UEM.TOTL.ZS
# --------------------------
# country AUS indicator EG.CFT.ACCS.ZS
# --------------------------
# country AUS indicator EG.ELC.ACCS.ZS
# --------------------------
# country AUS indicator SP.DYN.CBRT.IN
# --------------------------
# country AUS indicator SP.DYN.CDRT.IN
# --------------------------
# country AUS indicator SP.DYN.TFRT.IN
# --------------------------
# country AUS indicator HD.HCI.OVRL
# --------------------------
# country AUS indicator SP.DYN.LE00.IN
# --------------------------
# country AUS indicator EN.POP.DNST
# --------------------------
# country AUS indicator SP.POP.GROW
# --------------------------
# country AUS indicator EN.POP.EL5M.ZS
# --------------------------
# country AUS indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country AUS indicator SP.POP.TOTL
# --------------------------
# country AUS indicator SI.POV.DDAY
# --------------------------
# country AUS indicator SI.POV.LMIC
# --------------------------
# country AUS indicator SI.POV.UMIC
# --------------------------
# country AUS indicator SI.POV.NAHC
# --------------------------
# country AUS indicator SH.ALC.PCAP.LI
# --------------------------
# country AUS indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country AUS indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country AUS indicator FP.CPI.TOTL
# --------------------------
# country AUS indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country AUS indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country AUS indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country AUS indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country AUS indicator NY.GDP.PCAP.KD
# --------------------------
# country AUS indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country AUS indicator NE.CON.GOVT.ZS
# --------------------------
# country AUS indicator NY.GNP.PCAP.KD
# --------------------------
# country AUS indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country AUS indicator NV.IND.TOTL.ZS
# --------------------------
# country AUS indicator FP.CPI.TOTL.ZG
# --------------------------
# country AUS indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country AUS indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country AUS indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country AUT indicator AG.LND.AGRI.ZS
# --------------------------
# country AUT indicator AG.LND.PRCP.MM
# --------------------------
# country AUT indicator ER.H2O.FWST.ZS
# --------------------------
# country AUT indicator CC.EST
# --------------------------
# country AUT indicator IC.REG.COST.PC.ZS
# --------------------------
# country AUT indicator IC.BUS.DFRN.XQ
# --------------------------
# country AUT indicator IC.FRM.BNKS.ZS
# --------------------------
# country AUT indicator IC.REG.DURS
# --------------------------
# country AUT indicator SL.UEM.ADVN.ZS
# --------------------------
# country AUT indicator SL.UEM.BASC.ZS
# --------------------------
# country AUT indicator SL.UEM.INTM.ZS
# --------------------------
# country AUT indicator SL.UEM.TOTL.ZS
# --------------------------
# country AUT indicator EG.CFT.ACCS.ZS
# --------------------------
# country AUT indicator EG.ELC.ACCS.ZS
# --------------------------
# country AUT indicator SP.DYN.CBRT.IN
# --------------------------
# country AUT indicator SP.DYN.CDRT.IN
# --------------------------
# country AUT indicator SP.DYN.TFRT.IN
# --------------------------
# country AUT indicator HD.HCI.OVRL
# --------------------------
# country AUT indicator SP.DYN.LE00.IN
# --------------------------
# country AUT indicator EN.POP.DNST
# --------------------------
# country AUT indicator SP.POP.GROW
# --------------------------
# country AUT indicator EN.POP.EL5M.ZS
# --------------------------
# country AUT indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country AUT indicator SP.POP.TOTL
# --------------------------
# country AUT indicator SI.POV.DDAY
# --------------------------
# country AUT indicator SI.POV.LMIC
# --------------------------
# country AUT indicator SI.POV.UMIC
# --------------------------
# country AUT indicator SI.POV.NAHC
# --------------------------
# country AUT indicator SH.ALC.PCAP.LI
# --------------------------
# country AUT indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country AUT indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country AUT indicator FP.CPI.TOTL
# --------------------------
# country AUT indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country AUT indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country AUT indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country AUT indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country AUT indicator NY.GDP.PCAP.KD
# --------------------------
# country AUT indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country AUT indicator NE.CON.GOVT.ZS
# --------------------------
# country AUT indicator NY.GNP.PCAP.KD
# --------------------------
# country AUT indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country AUT indicator NV.IND.TOTL.ZS
# --------------------------
# country AUT indicator FP.CPI.TOTL.ZG
# --------------------------
# country AUT indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country AUT indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country AUT indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country AZE indicator AG.LND.AGRI.ZS
# --------------------------
# country AZE indicator AG.LND.PRCP.MM
# --------------------------
# country AZE indicator ER.H2O.FWST.ZS
# --------------------------
# country AZE indicator CC.EST
# --------------------------
# country AZE indicator IC.REG.COST.PC.ZS
# --------------------------
# country AZE indicator IC.BUS.DFRN.XQ
# --------------------------
# country AZE indicator IC.FRM.BNKS.ZS
# --------------------------
# country AZE indicator IC.REG.DURS
# --------------------------
# country AZE indicator SL.UEM.ADVN.ZS
# --------------------------
# country AZE indicator SL.UEM.BASC.ZS
# --------------------------
# country AZE indicator SL.UEM.INTM.ZS
# --------------------------
# country AZE indicator SL.UEM.TOTL.ZS
# --------------------------
# country AZE indicator EG.CFT.ACCS.ZS
# --------------------------
# country AZE indicator EG.ELC.ACCS.ZS
# --------------------------
# country AZE indicator SP.DYN.CBRT.IN
# --------------------------
# country AZE indicator SP.DYN.CDRT.IN
# --------------------------
# country AZE indicator SP.DYN.TFRT.IN
# --------------------------
# country AZE indicator HD.HCI.OVRL
# --------------------------
# country AZE indicator SP.DYN.LE00.IN
# --------------------------
# country AZE indicator EN.POP.DNST
# --------------------------
# country AZE indicator SP.POP.GROW
# --------------------------
# country AZE indicator EN.POP.EL5M.ZS
# --------------------------
# country AZE indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country AZE indicator SP.POP.TOTL
# --------------------------
# country AZE indicator SI.POV.DDAY
# --------------------------
# country AZE indicator SI.POV.LMIC
# --------------------------
# country AZE indicator SI.POV.UMIC
# --------------------------
# country AZE indicator SI.POV.NAHC
# --------------------------
# country AZE indicator SH.ALC.PCAP.LI
# --------------------------
# country AZE indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country AZE indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country AZE indicator FP.CPI.TOTL
# --------------------------
# country AZE indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country AZE indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country AZE indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country AZE indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country AZE indicator NY.GDP.PCAP.KD
# --------------------------
# country AZE indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country AZE indicator NE.CON.GOVT.ZS
# --------------------------
# country AZE indicator NY.GNP.PCAP.KD
# --------------------------
# country AZE indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country AZE indicator NV.IND.TOTL.ZS
# --------------------------
# country AZE indicator FP.CPI.TOTL.ZG
# --------------------------
# country AZE indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country AZE indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country AZE indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country BHS indicator AG.LND.AGRI.ZS
# --------------------------
# country BHS indicator AG.LND.PRCP.MM
# --------------------------
# country BHS indicator ER.H2O.FWST.ZS
# --------------------------
# country BHS indicator CC.EST
# --------------------------
# country BHS indicator IC.REG.COST.PC.ZS
# --------------------------
# country BHS indicator IC.BUS.DFRN.XQ
# --------------------------
# country BHS indicator IC.FRM.BNKS.ZS
# --------------------------
# country BHS indicator IC.REG.DURS
# --------------------------
# country BHS indicator SL.UEM.ADVN.ZS
# --------------------------
# country BHS indicator SL.UEM.BASC.ZS
# --------------------------
# country BHS indicator SL.UEM.INTM.ZS
# --------------------------
# country BHS indicator SL.UEM.TOTL.ZS
# --------------------------
# country BHS indicator EG.CFT.ACCS.ZS
# --------------------------
# country BHS indicator EG.ELC.ACCS.ZS
# --------------------------
# country BHS indicator SP.DYN.CBRT.IN
# --------------------------
# country BHS indicator SP.DYN.CDRT.IN
# --------------------------
# country BHS indicator SP.DYN.TFRT.IN
# --------------------------
# country BHS indicator HD.HCI.OVRL
# --------------------------
# country BHS indicator SP.DYN.LE00.IN
# --------------------------
# country BHS indicator EN.POP.DNST
# --------------------------
# country BHS indicator SP.POP.GROW
# --------------------------
# country BHS indicator EN.POP.EL5M.ZS
# --------------------------
# country BHS indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country BHS indicator SP.POP.TOTL
# --------------------------
# country BHS indicator SI.POV.DDAY
# --------------------------
# country BHS indicator SI.POV.LMIC
# --------------------------
# country BHS indicator SI.POV.UMIC
# --------------------------
# country BHS indicator SI.POV.NAHC
# --------------------------
# country BHS indicator SH.ALC.PCAP.LI
# --------------------------
# country BHS indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country BHS indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country BHS indicator FP.CPI.TOTL
# --------------------------
# country BHS indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country BHS indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country BHS indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country BHS indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country BHS indicator NY.GDP.PCAP.KD
# --------------------------
# country BHS indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country BHS indicator NE.CON.GOVT.ZS
# --------------------------
# country BHS indicator NY.GNP.PCAP.KD
# --------------------------
# country BHS indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country BHS indicator NV.IND.TOTL.ZS
# --------------------------
# country BHS indicator FP.CPI.TOTL.ZG
# --------------------------
# country BHS indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country BHS indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country BHS indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country BHR indicator AG.LND.AGRI.ZS
# --------------------------
# country BHR indicator AG.LND.PRCP.MM
# --------------------------
# country BHR indicator ER.H2O.FWST.ZS
# --------------------------
# country BHR indicator CC.EST
# --------------------------
# country BHR indicator IC.REG.COST.PC.ZS
# --------------------------
# country BHR indicator IC.BUS.DFRN.XQ
# --------------------------
# country BHR indicator IC.FRM.BNKS.ZS
# --------------------------
# country BHR indicator IC.REG.DURS
# --------------------------
# country BHR indicator SL.UEM.ADVN.ZS
# --------------------------
# country BHR indicator SL.UEM.BASC.ZS
# --------------------------
# country BHR indicator SL.UEM.INTM.ZS
# --------------------------
# country BHR indicator SL.UEM.TOTL.ZS
# --------------------------
# country BHR indicator EG.CFT.ACCS.ZS
# --------------------------
# country BHR indicator EG.ELC.ACCS.ZS
# --------------------------
# country BHR indicator SP.DYN.CBRT.IN
# --------------------------
# country BHR indicator SP.DYN.CDRT.IN
# --------------------------
# country BHR indicator SP.DYN.TFRT.IN
# --------------------------
# country BHR indicator HD.HCI.OVRL
# --------------------------
# country BHR indicator SP.DYN.LE00.IN
# --------------------------
# country BHR indicator EN.POP.DNST
# --------------------------
# country BHR indicator SP.POP.GROW
# --------------------------
# country BHR indicator EN.POP.EL5M.ZS
# --------------------------
# country BHR indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country BHR indicator SP.POP.TOTL
# --------------------------
# country BHR indicator SI.POV.DDAY
# --------------------------
# country BHR indicator SI.POV.LMIC
# --------------------------
# country BHR indicator SI.POV.UMIC
# --------------------------
# country BHR indicator SI.POV.NAHC
# --------------------------
# country BHR indicator SH.ALC.PCAP.LI
# --------------------------
# country BHR indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country BHR indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country BHR indicator FP.CPI.TOTL
# --------------------------
# country BHR indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country BHR indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country BHR indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country BHR indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country BHR indicator NY.GDP.PCAP.KD
# --------------------------
# country BHR indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country BHR indicator NE.CON.GOVT.ZS
# --------------------------
# country BHR indicator NY.GNP.PCAP.KD
# --------------------------
# country BHR indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country BHR indicator NV.IND.TOTL.ZS
# --------------------------
# country BHR indicator FP.CPI.TOTL.ZG
# --------------------------
# country BHR indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country BHR indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country BHR indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country BGD indicator AG.LND.AGRI.ZS
# --------------------------
# country BGD indicator AG.LND.PRCP.MM
# --------------------------
# country BGD indicator ER.H2O.FWST.ZS
# --------------------------
# country BGD indicator CC.EST
# --------------------------
# country BGD indicator IC.REG.COST.PC.ZS
# --------------------------
# country BGD indicator IC.BUS.DFRN.XQ
# --------------------------
# country BGD indicator IC.FRM.BNKS.ZS
# --------------------------
# country BGD indicator IC.REG.DURS
# --------------------------
# country BGD indicator SL.UEM.ADVN.ZS
# --------------------------
# country BGD indicator SL.UEM.BASC.ZS
# --------------------------
# country BGD indicator SL.UEM.INTM.ZS
# --------------------------
# country BGD indicator SL.UEM.TOTL.ZS
# --------------------------
# country BGD indicator EG.CFT.ACCS.ZS
# --------------------------
# country BGD indicator EG.ELC.ACCS.ZS
# --------------------------
# country BGD indicator SP.DYN.CBRT.IN
# --------------------------
# country BGD indicator SP.DYN.CDRT.IN
# --------------------------
# country BGD indicator SP.DYN.TFRT.IN
# --------------------------
# country BGD indicator HD.HCI.OVRL
# --------------------------
# country BGD indicator SP.DYN.LE00.IN
# --------------------------
# country BGD indicator EN.POP.DNST
# --------------------------
# country BGD indicator SP.POP.GROW
# --------------------------
# country BGD indicator EN.POP.EL5M.ZS
# --------------------------
# country BGD indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country BGD indicator SP.POP.TOTL
# --------------------------
# country BGD indicator SI.POV.DDAY
# --------------------------
# country BGD indicator SI.POV.LMIC
# --------------------------
# country BGD indicator SI.POV.UMIC
# --------------------------
# country BGD indicator SI.POV.NAHC
# --------------------------
# country BGD indicator SH.ALC.PCAP.LI
# --------------------------
# country BGD indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country BGD indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country BGD indicator FP.CPI.TOTL
# --------------------------
# country BGD indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country BGD indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country BGD indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country BGD indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country BGD indicator NY.GDP.PCAP.KD
# --------------------------
# country BGD indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country BGD indicator NE.CON.GOVT.ZS
# --------------------------
# country BGD indicator NY.GNP.PCAP.KD
# --------------------------
# country BGD indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country BGD indicator NV.IND.TOTL.ZS
# --------------------------
# country BGD indicator FP.CPI.TOTL.ZG
# --------------------------
# country BGD indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country BGD indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country BGD indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country BRB indicator AG.LND.AGRI.ZS
# --------------------------
# country BRB indicator AG.LND.PRCP.MM
# --------------------------
# country BRB indicator ER.H2O.FWST.ZS
# --------------------------
# country BRB indicator CC.EST
# --------------------------
# country BRB indicator IC.REG.COST.PC.ZS
# --------------------------
# country BRB indicator IC.BUS.DFRN.XQ
# --------------------------
# country BRB indicator IC.FRM.BNKS.ZS
# --------------------------
# country BRB indicator IC.REG.DURS
# --------------------------
# country BRB indicator SL.UEM.ADVN.ZS
# --------------------------
# country BRB indicator SL.UEM.BASC.ZS
# --------------------------
# country BRB indicator SL.UEM.INTM.ZS
# --------------------------
# country BRB indicator SL.UEM.TOTL.ZS
# --------------------------
# country BRB indicator EG.CFT.ACCS.ZS
# --------------------------
# country BRB indicator EG.ELC.ACCS.ZS
# --------------------------
# country BRB indicator SP.DYN.CBRT.IN
# --------------------------
# country BRB indicator SP.DYN.CDRT.IN
# --------------------------
# country BRB indicator SP.DYN.TFRT.IN
# --------------------------
# country BRB indicator HD.HCI.OVRL
# --------------------------
# country BRB indicator SP.DYN.LE00.IN
# --------------------------
# country BRB indicator EN.POP.DNST
# --------------------------
# country BRB indicator SP.POP.GROW
# --------------------------
# country BRB indicator EN.POP.EL5M.ZS
# --------------------------
# country BRB indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country BRB indicator SP.POP.TOTL
# --------------------------
# country BRB indicator SI.POV.DDAY
# --------------------------
# country BRB indicator SI.POV.LMIC
# --------------------------
# country BRB indicator SI.POV.UMIC
# --------------------------
# country BRB indicator SI.POV.NAHC
# --------------------------
# country BRB indicator SH.ALC.PCAP.LI
# --------------------------
# country BRB indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country BRB indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country BRB indicator FP.CPI.TOTL
# --------------------------
# country BRB indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country BRB indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country BRB indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country BRB indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country BRB indicator NY.GDP.PCAP.KD
# --------------------------
# country BRB indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country BRB indicator NE.CON.GOVT.ZS
# --------------------------
# country BRB indicator NY.GNP.PCAP.KD
# --------------------------
# country BRB indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country BRB indicator NV.IND.TOTL.ZS
# --------------------------
# country BRB indicator FP.CPI.TOTL.ZG
# --------------------------
# country BRB indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country BRB indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country BRB indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country BLR indicator AG.LND.AGRI.ZS
# --------------------------
# country BLR indicator AG.LND.PRCP.MM
# --------------------------
# country BLR indicator ER.H2O.FWST.ZS
# --------------------------
# country BLR indicator CC.EST
# --------------------------
# country BLR indicator IC.REG.COST.PC.ZS
# --------------------------
# country BLR indicator IC.BUS.DFRN.XQ
# --------------------------
# country BLR indicator IC.FRM.BNKS.ZS
# --------------------------
# country BLR indicator IC.REG.DURS
# --------------------------
# country BLR indicator SL.UEM.ADVN.ZS
# --------------------------
# country BLR indicator SL.UEM.BASC.ZS
# --------------------------
# country BLR indicator SL.UEM.INTM.ZS
# --------------------------
# country BLR indicator SL.UEM.TOTL.ZS
# --------------------------
# country BLR indicator EG.CFT.ACCS.ZS
# --------------------------
# country BLR indicator EG.ELC.ACCS.ZS
# --------------------------
# country BLR indicator SP.DYN.CBRT.IN
# --------------------------
# country BLR indicator SP.DYN.CDRT.IN
# --------------------------
# country BLR indicator SP.DYN.TFRT.IN
# --------------------------
# country BLR indicator HD.HCI.OVRL
# --------------------------
# country BLR indicator SP.DYN.LE00.IN
# --------------------------
# country BLR indicator EN.POP.DNST
# --------------------------
# country BLR indicator SP.POP.GROW
# --------------------------
# country BLR indicator EN.POP.EL5M.ZS
# --------------------------
# country BLR indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country BLR indicator SP.POP.TOTL
# --------------------------
# country BLR indicator SI.POV.DDAY
# --------------------------
# country BLR indicator SI.POV.LMIC
# --------------------------
# country BLR indicator SI.POV.UMIC
# --------------------------
# country BLR indicator SI.POV.NAHC
# --------------------------
# country BLR indicator SH.ALC.PCAP.LI
# --------------------------
# country BLR indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country BLR indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country BLR indicator FP.CPI.TOTL
# --------------------------
# country BLR indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country BLR indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country BLR indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country BLR indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country BLR indicator NY.GDP.PCAP.KD
# --------------------------
# country BLR indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country BLR indicator NE.CON.GOVT.ZS
# --------------------------
# country BLR indicator NY.GNP.PCAP.KD
# --------------------------
# country BLR indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country BLR indicator NV.IND.TOTL.ZS
# --------------------------
# country BLR indicator FP.CPI.TOTL.ZG
# --------------------------
# country BLR indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country BLR indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country BLR indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country BEL indicator AG.LND.AGRI.ZS
# --------------------------
# country BEL indicator AG.LND.PRCP.MM
# --------------------------
# country BEL indicator ER.H2O.FWST.ZS
# --------------------------
# country BEL indicator CC.EST
# --------------------------
# country BEL indicator IC.REG.COST.PC.ZS
# --------------------------
# country BEL indicator IC.BUS.DFRN.XQ
# --------------------------
# country BEL indicator IC.FRM.BNKS.ZS
# --------------------------
# country BEL indicator IC.REG.DURS
# --------------------------
# country BEL indicator SL.UEM.ADVN.ZS
# --------------------------
# country BEL indicator SL.UEM.BASC.ZS
# --------------------------
# country BEL indicator SL.UEM.INTM.ZS
# --------------------------
# country BEL indicator SL.UEM.TOTL.ZS
# --------------------------
# country BEL indicator EG.CFT.ACCS.ZS
# --------------------------
# country BEL indicator EG.ELC.ACCS.ZS
# --------------------------
# country BEL indicator SP.DYN.CBRT.IN
# --------------------------
# country BEL indicator SP.DYN.CDRT.IN
# --------------------------
# country BEL indicator SP.DYN.TFRT.IN
# --------------------------
# country BEL indicator HD.HCI.OVRL
# --------------------------
# country BEL indicator SP.DYN.LE00.IN
# --------------------------
# country BEL indicator EN.POP.DNST
# --------------------------
# country BEL indicator SP.POP.GROW
# --------------------------
# country BEL indicator EN.POP.EL5M.ZS
# --------------------------
# country BEL indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country BEL indicator SP.POP.TOTL
# --------------------------
# country BEL indicator SI.POV.DDAY
# --------------------------
# country BEL indicator SI.POV.LMIC
# --------------------------
# country BEL indicator SI.POV.UMIC
# --------------------------
# country BEL indicator SI.POV.NAHC
# --------------------------
# country BEL indicator SH.ALC.PCAP.LI
# --------------------------
# country BEL indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country BEL indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country BEL indicator FP.CPI.TOTL
# --------------------------
# country BEL indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country BEL indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country BEL indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country BEL indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country BEL indicator NY.GDP.PCAP.KD
# --------------------------
# country BEL indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country BEL indicator NE.CON.GOVT.ZS
# --------------------------
# country BEL indicator NY.GNP.PCAP.KD
# --------------------------
# country BEL indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country BEL indicator NV.IND.TOTL.ZS
# --------------------------
# country BEL indicator FP.CPI.TOTL.ZG
# --------------------------
# country BEL indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country BEL indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country BEL indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country BLZ indicator AG.LND.AGRI.ZS
# --------------------------
# country BLZ indicator AG.LND.PRCP.MM
# --------------------------
# country BLZ indicator ER.H2O.FWST.ZS
# --------------------------
# country BLZ indicator CC.EST
# --------------------------
# country BLZ indicator IC.REG.COST.PC.ZS
# --------------------------
# country BLZ indicator IC.BUS.DFRN.XQ
# --------------------------
# country BLZ indicator IC.FRM.BNKS.ZS
# --------------------------
# country BLZ indicator IC.REG.DURS
# --------------------------
# country BLZ indicator SL.UEM.ADVN.ZS
# --------------------------
# country BLZ indicator SL.UEM.BASC.ZS
# --------------------------
# country BLZ indicator SL.UEM.INTM.ZS
# --------------------------
# country BLZ indicator SL.UEM.TOTL.ZS
# --------------------------
# country BLZ indicator EG.CFT.ACCS.ZS
# --------------------------
# country BLZ indicator EG.ELC.ACCS.ZS
# --------------------------
# country BLZ indicator SP.DYN.CBRT.IN
# --------------------------
# country BLZ indicator SP.DYN.CDRT.IN
# --------------------------
# country BLZ indicator SP.DYN.TFRT.IN
# --------------------------
# country BLZ indicator HD.HCI.OVRL
# --------------------------
# country BLZ indicator SP.DYN.LE00.IN
# --------------------------
# country BLZ indicator EN.POP.DNST
# --------------------------
# country BLZ indicator SP.POP.GROW
# --------------------------
# country BLZ indicator EN.POP.EL5M.ZS
# --------------------------
# country BLZ indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country BLZ indicator SP.POP.TOTL
# --------------------------
# country BLZ indicator SI.POV.DDAY
# --------------------------
# country BLZ indicator SI.POV.LMIC
# --------------------------
# country BLZ indicator SI.POV.UMIC
# --------------------------
# country BLZ indicator SI.POV.NAHC
# --------------------------
# country BLZ indicator SH.ALC.PCAP.LI
# --------------------------
# country BLZ indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country BLZ indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country BLZ indicator FP.CPI.TOTL
# --------------------------
# country BLZ indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country BLZ indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country BLZ indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country BLZ indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country BLZ indicator NY.GDP.PCAP.KD
# --------------------------
# country BLZ indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country BLZ indicator NE.CON.GOVT.ZS
# --------------------------
# country BLZ indicator NY.GNP.PCAP.KD
# --------------------------
# country BLZ indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country BLZ indicator NV.IND.TOTL.ZS
# --------------------------
# country BLZ indicator FP.CPI.TOTL.ZG
# --------------------------
# country BLZ indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country BLZ indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country BLZ indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country BEN indicator AG.LND.AGRI.ZS
# --------------------------
# country BEN indicator AG.LND.PRCP.MM
# --------------------------
# country BEN indicator ER.H2O.FWST.ZS
# --------------------------
# country BEN indicator CC.EST
# --------------------------
# country BEN indicator IC.REG.COST.PC.ZS
# --------------------------
# country BEN indicator IC.BUS.DFRN.XQ
# --------------------------
# country BEN indicator IC.FRM.BNKS.ZS
# --------------------------
# country BEN indicator IC.REG.DURS
# --------------------------
# country BEN indicator SL.UEM.ADVN.ZS
# --------------------------
# country BEN indicator SL.UEM.BASC.ZS
# --------------------------
# country BEN indicator SL.UEM.INTM.ZS
# --------------------------
# country BEN indicator SL.UEM.TOTL.ZS
# --------------------------
# country BEN indicator EG.CFT.ACCS.ZS
# ...
# --------------------------
# country PYF indicator SI.POV.NAHC
# --------------------------
# country PYF indicator SH.ALC.PCAP.LI
# --------------------------
# country PYF indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country PYF indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country PYF indicator FP.CPI.TOTL
# --------------------------
# country PYF indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country PYF indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country PYF indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country PYF indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country PYF indicator NY.GDP.PCAP.KD
# --------------------------
# country PYF indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country PYF indicator NE.CON.GOVT.ZS
# --------------------------
# country PYF indicator NY.GNP.PCAP.KD
# --------------------------
# country PYF indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country PYF indicator NV.IND.TOTL.ZS
# --------------------------
# country PYF indicator FP.CPI.TOTL.ZG
# --------------------------
# country PYF indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country PYF indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country PYF indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country NRU indicator AG.LND.AGRI.ZS
# --------------------------
# country NRU indicator AG.LND.PRCP.MM
# --------------------------
# country NRU indicator ER.H2O.FWST.ZS
# --------------------------
# country NRU indicator CC.EST
# --------------------------
# country NRU indicator IC.REG.COST.PC.ZS
# --------------------------
# country NRU indicator IC.BUS.DFRN.XQ
# --------------------------
# country NRU indicator IC.FRM.BNKS.ZS
# --------------------------
# country NRU indicator IC.REG.DURS
# --------------------------
# country NRU indicator SL.UEM.ADVN.ZS
# --------------------------
# country NRU indicator SL.UEM.BASC.ZS
# --------------------------
# country NRU indicator SL.UEM.INTM.ZS
# --------------------------
# country NRU indicator SL.UEM.TOTL.ZS
# --------------------------
# country NRU indicator EG.CFT.ACCS.ZS
# --------------------------
# country NRU indicator EG.ELC.ACCS.ZS
# --------------------------
# country NRU indicator SP.DYN.CBRT.IN
# --------------------------
# country NRU indicator SP.DYN.CDRT.IN
# --------------------------
# country NRU indicator SP.DYN.TFRT.IN
# --------------------------
# country NRU indicator HD.HCI.OVRL
# --------------------------
# country NRU indicator SP.DYN.LE00.IN
# --------------------------
# country NRU indicator EN.POP.DNST
# --------------------------
# country NRU indicator SP.POP.GROW
# --------------------------
# country NRU indicator EN.POP.EL5M.ZS
# --------------------------
# country NRU indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country NRU indicator SP.POP.TOTL
# --------------------------
# country NRU indicator SI.POV.DDAY
# --------------------------
# country NRU indicator SI.POV.LMIC
# --------------------------
# country NRU indicator SI.POV.UMIC
# --------------------------
# country NRU indicator SI.POV.NAHC
# --------------------------
# country NRU indicator SH.ALC.PCAP.LI
# --------------------------
# country NRU indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country NRU indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country NRU indicator FP.CPI.TOTL
# --------------------------
# country NRU indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country NRU indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country NRU indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country NRU indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country NRU indicator NY.GDP.PCAP.KD
# --------------------------
# country NRU indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country NRU indicator NE.CON.GOVT.ZS
# --------------------------
# country NRU indicator NY.GNP.PCAP.KD
# --------------------------
# country NRU indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country NRU indicator NV.IND.TOTL.ZS
# --------------------------
# country NRU indicator FP.CPI.TOTL.ZG
# --------------------------
# country NRU indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country NRU indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country NRU indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country STP indicator AG.LND.AGRI.ZS
# --------------------------
# country STP indicator AG.LND.PRCP.MM
# --------------------------
# country STP indicator ER.H2O.FWST.ZS
# --------------------------
# country STP indicator CC.EST
# --------------------------
# country STP indicator IC.REG.COST.PC.ZS
# --------------------------
# country STP indicator IC.BUS.DFRN.XQ
# --------------------------
# country STP indicator IC.FRM.BNKS.ZS
# --------------------------
# country STP indicator IC.REG.DURS
# --------------------------
# country STP indicator SL.UEM.ADVN.ZS
# --------------------------
# country STP indicator SL.UEM.BASC.ZS
# --------------------------
# country STP indicator SL.UEM.INTM.ZS
# --------------------------
# country STP indicator SL.UEM.TOTL.ZS
# --------------------------
# country STP indicator EG.CFT.ACCS.ZS
# --------------------------
# country STP indicator EG.ELC.ACCS.ZS
# --------------------------
# country STP indicator SP.DYN.CBRT.IN
# --------------------------
# country STP indicator SP.DYN.CDRT.IN
# --------------------------
# country STP indicator SP.DYN.TFRT.IN
# --------------------------
# country STP indicator HD.HCI.OVRL
# --------------------------
# country STP indicator SP.DYN.LE00.IN
# --------------------------
# country STP indicator EN.POP.DNST
# --------------------------
# country STP indicator SP.POP.GROW
# --------------------------
# country STP indicator EN.POP.EL5M.ZS
# --------------------------
# country STP indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country STP indicator SP.POP.TOTL
# --------------------------
# country STP indicator SI.POV.DDAY
# --------------------------
# country STP indicator SI.POV.LMIC
# --------------------------
# country STP indicator SI.POV.UMIC
# --------------------------
# country STP indicator SI.POV.NAHC
# --------------------------
# country STP indicator SH.ALC.PCAP.LI
# --------------------------
# country STP indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country STP indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country STP indicator FP.CPI.TOTL
# --------------------------
# country STP indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country STP indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country STP indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country STP indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country STP indicator NY.GDP.PCAP.KD
# --------------------------
# country STP indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country STP indicator NE.CON.GOVT.ZS
# --------------------------
# country STP indicator NY.GNP.PCAP.KD
# --------------------------
# country STP indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country STP indicator NV.IND.TOTL.ZS
# --------------------------
# country STP indicator FP.CPI.TOTL.ZG
# --------------------------
# country STP indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country STP indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country STP indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country VUT indicator AG.LND.AGRI.ZS
# --------------------------
# country VUT indicator AG.LND.PRCP.MM
# --------------------------
# country VUT indicator ER.H2O.FWST.ZS
# --------------------------
# country VUT indicator CC.EST
# --------------------------
# country VUT indicator IC.REG.COST.PC.ZS
# --------------------------
# country VUT indicator IC.BUS.DFRN.XQ
# --------------------------
# country VUT indicator IC.FRM.BNKS.ZS
# --------------------------
# country VUT indicator IC.REG.DURS
# --------------------------
# country VUT indicator SL.UEM.ADVN.ZS
# --------------------------
# country VUT indicator SL.UEM.BASC.ZS
# --------------------------
# country VUT indicator SL.UEM.INTM.ZS
# --------------------------
# country VUT indicator SL.UEM.TOTL.ZS
# --------------------------
# country VUT indicator EG.CFT.ACCS.ZS
# --------------------------
# country VUT indicator EG.ELC.ACCS.ZS
# --------------------------
# country VUT indicator SP.DYN.CBRT.IN
# --------------------------
# country VUT indicator SP.DYN.CDRT.IN
# --------------------------
# country VUT indicator SP.DYN.TFRT.IN
# --------------------------
# country VUT indicator HD.HCI.OVRL
# --------------------------
# country VUT indicator SP.DYN.LE00.IN
# --------------------------
# country VUT indicator EN.POP.DNST
# --------------------------
# country VUT indicator SP.POP.GROW
# --------------------------
# country VUT indicator EN.POP.EL5M.ZS
# --------------------------
# country VUT indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country VUT indicator SP.POP.TOTL
# --------------------------
# country VUT indicator SI.POV.DDAY
# --------------------------
# country VUT indicator SI.POV.LMIC
# --------------------------
# country VUT indicator SI.POV.UMIC
# --------------------------
# country VUT indicator SI.POV.NAHC
# --------------------------
# country VUT indicator SH.ALC.PCAP.LI
# --------------------------
# country VUT indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country VUT indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country VUT indicator FP.CPI.TOTL
# --------------------------
# country VUT indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country VUT indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country VUT indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country VUT indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country VUT indicator NY.GDP.PCAP.KD
# --------------------------
# country VUT indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country VUT indicator NE.CON.GOVT.ZS
# --------------------------
# country VUT indicator NY.GNP.PCAP.KD
# --------------------------
# country VUT indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country VUT indicator NV.IND.TOTL.ZS
# --------------------------
# country VUT indicator FP.CPI.TOTL.ZG
# --------------------------
# country VUT indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country VUT indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country VUT indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country SXM indicator AG.LND.AGRI.ZS
# --------------------------
# country SXM indicator AG.LND.PRCP.MM
# --------------------------
# country SXM indicator ER.H2O.FWST.ZS
# --------------------------
# country SXM indicator CC.EST
# --------------------------
# country SXM indicator IC.REG.COST.PC.ZS
# --------------------------
# country SXM indicator IC.BUS.DFRN.XQ
# --------------------------
# country SXM indicator IC.FRM.BNKS.ZS
# --------------------------
# country SXM indicator IC.REG.DURS
# --------------------------
# country SXM indicator SL.UEM.ADVN.ZS
# --------------------------
# country SXM indicator SL.UEM.BASC.ZS
# --------------------------
# country SXM indicator SL.UEM.INTM.ZS
# --------------------------
# country SXM indicator SL.UEM.TOTL.ZS
# --------------------------
# country SXM indicator EG.CFT.ACCS.ZS
# --------------------------
# country SXM indicator EG.ELC.ACCS.ZS
# --------------------------
# country SXM indicator SP.DYN.CBRT.IN
# --------------------------
# country SXM indicator SP.DYN.CDRT.IN
# --------------------------
# country SXM indicator SP.DYN.TFRT.IN
# --------------------------
# country SXM indicator HD.HCI.OVRL
# --------------------------
# country SXM indicator SP.DYN.LE00.IN
# --------------------------
# country SXM indicator EN.POP.DNST
# --------------------------
# country SXM indicator SP.POP.GROW
# --------------------------
# country SXM indicator EN.POP.EL5M.ZS
# --------------------------
# country SXM indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country SXM indicator SP.POP.TOTL
# --------------------------
# country SXM indicator SI.POV.DDAY
# --------------------------
# country SXM indicator SI.POV.LMIC
# --------------------------
# country SXM indicator SI.POV.UMIC
# --------------------------
# country SXM indicator SI.POV.NAHC
# --------------------------
# country SXM indicator SH.ALC.PCAP.LI
# --------------------------
# country SXM indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country SXM indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country SXM indicator FP.CPI.TOTL
# --------------------------
# country SXM indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country SXM indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country SXM indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country SXM indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country SXM indicator NY.GDP.PCAP.KD
# --------------------------
# country SXM indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country SXM indicator NE.CON.GOVT.ZS
# --------------------------
# country SXM indicator NY.GNP.PCAP.KD
# --------------------------
# country SXM indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country SXM indicator NV.IND.TOTL.ZS
# --------------------------
# country SXM indicator FP.CPI.TOTL.ZG
# --------------------------
# country SXM indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country SXM indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country SXM indicator DT.TDS.DECT.GN.ZS
# --------------------------
# country TCA indicator AG.LND.AGRI.ZS
# --------------------------
# country TCA indicator AG.LND.PRCP.MM
# --------------------------
# country TCA indicator ER.H2O.FWST.ZS
# --------------------------
# country TCA indicator CC.EST
# --------------------------
# country TCA indicator IC.REG.COST.PC.ZS
# --------------------------
# country TCA indicator IC.BUS.DFRN.XQ
# --------------------------
# country TCA indicator IC.FRM.BNKS.ZS
# --------------------------
# country TCA indicator IC.REG.DURS
# --------------------------
# country TCA indicator SL.UEM.ADVN.ZS
# --------------------------
# country TCA indicator SL.UEM.BASC.ZS
# --------------------------
# country TCA indicator SL.UEM.INTM.ZS
# --------------------------
# country TCA indicator SL.UEM.TOTL.ZS
# --------------------------
# country TCA indicator EG.CFT.ACCS.ZS
# --------------------------
# country TCA indicator EG.ELC.ACCS.ZS
# --------------------------
# country TCA indicator SP.DYN.CBRT.IN
# --------------------------
# country TCA indicator SP.DYN.CDRT.IN
# --------------------------
# country TCA indicator SP.DYN.TFRT.IN
# --------------------------
# country TCA indicator HD.HCI.OVRL
# --------------------------
# country TCA indicator SP.DYN.LE00.IN
# --------------------------
# country TCA indicator EN.POP.DNST
# --------------------------
# country TCA indicator SP.POP.GROW
# --------------------------
# country TCA indicator EN.POP.EL5M.ZS
# --------------------------
# country TCA indicator EN.POP.SLUM.UR.ZS
# --------------------------
# country TCA indicator SP.POP.TOTL
# --------------------------
# country TCA indicator SI.POV.DDAY
# --------------------------
# country TCA indicator SI.POV.LMIC
# --------------------------
# country TCA indicator SI.POV.UMIC
# --------------------------
# country TCA indicator SI.POV.NAHC
# --------------------------
# country TCA indicator SH.ALC.PCAP.LI
# --------------------------
# country TCA indicator MS.MIL.TOTL.TF.ZS
# --------------------------
# country TCA indicator GC.DOD.TOTL.GD.ZS
# --------------------------
# country TCA indicator FP.CPI.TOTL
# --------------------------
# country TCA indicator BN.CAB.XOKA.GD.ZS
# --------------------------
# country TCA indicator SH.XPD.CHEX.GD.ZS
# --------------------------
# country TCA indicator DT.TDS.DPPF.XP.ZS
# --------------------------
# country TCA indicator NY.GDP.MKTP.KD.ZG
# --------------------------
# country TCA indicator NY.GDP.PCAP.KD
# --------------------------
# country TCA indicator NY.GDP.PCAP.PP.KD
# --------------------------
# country TCA indicator NE.CON.GOVT.ZS
# --------------------------
# country TCA indicator NY.GNP.PCAP.KD
# --------------------------
# country TCA indicator SE.XPD.TOTL.GD.ZS
# --------------------------
# country TCA indicator NV.IND.TOTL.ZS
# --------------------------
# country TCA indicator FP.CPI.TOTL.ZG
# --------------------------
# country TCA indicator MS.MIL.XPND.GD.ZS
# --------------------------
# country TCA indicator DT.TDS.DECT.EX.ZS
# --------------------------
# country TCA indicator DT.TDS.DECT.GN.ZS

# %%
## Create DF with the previous output

raw_macrodata_df = pd.DataFrame(macro_eco_data_list)

raw_macrodata_df.head()
# Out:
#   iso3Code iso2Code      country  year                           indicator  \
# 0      AFG       AF  Afghanistan  2023  Agricultural land (% of land area)
# 1      AFG       AF  Afghanistan  2022  Agricultural land (% of land area)
# 2      AFG       AF  Afghanistan  2021  Agricultural land (% of land area)
# 3      AFG       AF  Afghanistan  2020  Agricultural land (% of land area)
# 4      AFG       AF  Afghanistan  2019  Agricultural land (% of land area)
#
#        value
# 0        NaN
# 1  58.741548
# 2  58.741548
# 3  58.741548
# 4  58.276988

# %% [markdown]
# ### 3.1 the next steps will replace each nan value with the previous value available
# to do :
# - we pivot the DF with years as column
# - we replace 2015 nan values with 0
# - we replace all other nan values with the previous value (using fillna(method='ffill', axis=1))

# %%
raw_macrodata_df.shape
# Out:
# (83835, 6)

# %%
temp_df = raw_macrodata_df.pivot_table(index=['indicator', 'country','iso3Code','iso2Code'], columns='year', values='value')
temp_df.head()
# Out:
# year                                                                               2015  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         27.6
#                                                    Albania     ALB      AL         76.6
#                                                    Algeria     DZA      DZ         99.6
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         47.3
#
# year                                                                               2016  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         28.8
#                                                    Albania     ALB      AL         78.3
#                                                    Algeria     DZA      DZ         99.6
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         47.8
#
# year                                                                               2017  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         30.3
#                                                    Albania     ALB      AL         79.6
#                                                    Algeria     DZA      DZ         99.7
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         48.3
#
# year                                                                               2018  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         31.4
#                                                    Albania     ALB      AL         80.7
#                                                    Algeria     DZA      DZ         99.7
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         48.6
#
# year                                                                               2019  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         32.6
#                                                    Albania     ALB      AL         82.0
#                                                    Algeria     DZA      DZ         99.7
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         49.0
#
# year                                                                               2020  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         33.8
#                                                    Albania     ALB      AL         83.1
#                                                    Algeria     DZA      DZ         99.7
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         49.7
#
# year                                                                               2021  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         34.9
#                                                    Albania     ALB      AL         83.6
#                                                    Algeria     DZA      DZ         99.7
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         49.8
#
# year                                                                               2022  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         36.1
#                                                    Albania     ALB      AL         84.6
#                                                    Algeria     DZA      DZ         99.7
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         50.0
#
# year                                                                              2023
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         NaN
#                                                    Albania     ALB      AL         NaN
#                                                    Algeria     DZA      DZ         NaN
#                                                    Andorra     AND      AD         NaN
#                                                    Angola      AGO      AO         NaN

# %%
temp_pivot = temp_df.fillna({'2015' : 0})
temp_pivot.head()
# Out:
# year                                                                               2015  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         27.6
#                                                    Albania     ALB      AL         76.6
#                                                    Algeria     DZA      DZ         99.6
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         47.3
#
# year                                                                               2016  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         28.8
#                                                    Albania     ALB      AL         78.3
#                                                    Algeria     DZA      DZ         99.6
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         47.8
#
# year                                                                               2017  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         30.3
#                                                    Albania     ALB      AL         79.6
#                                                    Algeria     DZA      DZ         99.7
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         48.3
#
# year                                                                               2018  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         31.4
#                                                    Albania     ALB      AL         80.7
#                                                    Algeria     DZA      DZ         99.7
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         48.6
#
# year                                                                               2019  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         32.6
#                                                    Albania     ALB      AL         82.0
#                                                    Algeria     DZA      DZ         99.7
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         49.0
#
# year                                                                               2020  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         33.8
#                                                    Albania     ALB      AL         83.1
#                                                    Algeria     DZA      DZ         99.7
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         49.7
#
# year                                                                               2021  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         34.9
#                                                    Albania     ALB      AL         83.6
#                                                    Algeria     DZA      DZ         99.7
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         49.8
#
# year                                                                               2022  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         36.1
#                                                    Albania     ALB      AL         84.6
#                                                    Algeria     DZA      DZ         99.7
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         50.0
#
# year                                                                              2023
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         NaN
#                                                    Albania     ALB      AL         NaN
#                                                    Algeria     DZA      DZ         NaN
#                                                    Andorra     AND      AD         NaN
#                                                    Angola      AGO      AO         NaN

# %%
temp_pivot = temp_pivot.fillna(method='ffill', axis=1)
temp_pivot.head()
# Out:
# C:\Users\nazim\AppData\Local\Temp\ipykernel_11168\1304417063.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   temp_pivot = temp_pivot.fillna(method='ffill', axis=1)
# year                                                                               2015  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         27.6
#                                                    Albania     ALB      AL         76.6
#                                                    Algeria     DZA      DZ         99.6
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         47.3
#
# year                                                                               2016  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         28.8
#                                                    Albania     ALB      AL         78.3
#                                                    Algeria     DZA      DZ         99.6
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         47.8
#
# year                                                                               2017  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         30.3
#                                                    Albania     ALB      AL         79.6
#                                                    Algeria     DZA      DZ         99.7
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         48.3
#
# year                                                                               2018  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         31.4
#                                                    Albania     ALB      AL         80.7
#                                                    Algeria     DZA      DZ         99.7
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         48.6
#
# year                                                                               2019  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         32.6
#                                                    Albania     ALB      AL         82.0
#                                                    Algeria     DZA      DZ         99.7
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         49.0
#
# year                                                                               2020  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         33.8
#                                                    Albania     ALB      AL         83.1
#                                                    Algeria     DZA      DZ         99.7
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         49.7
#
# year                                                                               2021  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         34.9
#                                                    Albania     ALB      AL         83.6
#                                                    Algeria     DZA      DZ         99.7
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         49.8
#
# year                                                                               2022  \
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         36.1
#                                                    Albania     ALB      AL         84.6
#                                                    Algeria     DZA      DZ         99.7
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         50.0
#
# year                                                                               2023
# indicator                                          country     iso3Code iso2Code
# Access to clean fuels and technologies for cook... Afghanistan AFG      AF         36.1
#                                                    Albania     ALB      AL         84.6
#                                                    Algeria     DZA      DZ         99.7
#                                                    Andorra     AND      AD        100.0
#                                                    Angola      AGO      AO         50.0

# %%
temp_pivot = temp_pivot.reset_index()
temp_pivot.columns
# Out:
# Index(['indicator', 'country', 'iso3Code', 'iso2Code', '2015', '2016', '2017',
#        '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype='object', name='year')

# %%
temp_pivot.head()
# Out:
# year                                          indicator      country iso3Code  \
# 0     Access to clean fuels and technologies for coo...  Afghanistan      AFG
# 1     Access to clean fuels and technologies for coo...      Albania      ALB
# 2     Access to clean fuels and technologies for coo...      Algeria      DZA
# 3     Access to clean fuels and technologies for coo...      Andorra      AND
# 4     Access to clean fuels and technologies for coo...       Angola      AGO
#
# year iso2Code   2015   2016   2017   2018   2019   2020   2021   2022   2023
# 0          AF   27.6   28.8   30.3   31.4   32.6   33.8   34.9   36.1   36.1
# 1          AL   76.6   78.3   79.6   80.7   82.0   83.1   83.6   84.6   84.6
# 2          DZ   99.6   99.6   99.7   99.7   99.7   99.7   99.7   99.7   99.7
# 3          AD  100.0  100.0  100.0  100.0  100.0  100.0  100.0  100.0  100.0
# 4          AO   47.3   47.8   48.3   48.6   49.0   49.7   49.8   50.0   50.0

# %%
macro_eco_data_df = pd.melt(temp_pivot, id_vars=['indicator', 'country','iso3Code','iso2Code'], var_name='year', value_name='value' )
macro_eco_data_df
# Out:
#                                                indicator             country  \
# 0      Access to clean fuels and technologies for coo...         Afghanistan
# 1      Access to clean fuels and technologies for coo...             Albania
# 2      Access to clean fuels and technologies for coo...             Algeria
# 3      Access to clean fuels and technologies for coo...             Andorra
# 4      Access to clean fuels and technologies for coo...              Angola
# ...                                                  ...                 ...
# 71626  Unemployment, total (% of total labor force) (...            Viet Nam
# 71627  Unemployment, total (% of total labor force) (...  West Bank and Gaza
# 71628  Unemployment, total (% of total labor force) (...         Yemen, Rep.
# 71629  Unemployment, total (% of total labor force) (...              Zambia
# 71630  Unemployment, total (% of total labor force) (...            Zimbabwe
#
#       iso3Code iso2Code  year    value
# 0          AFG       AF  2015   27.600
# 1          ALB       AL  2015   76.600
# 2          DZA       DZ  2015   99.600
# 3          AND       AD  2015  100.000
# 4          AGO       AO  2015   47.300
# ...        ...      ...   ...      ...
# 71626      VNM       VN  2023    1.645
# 71627      PSE       PS  2023   24.420
# 71628      YEM       YE  2023   17.091
# 71629      ZMB       ZM  2023    5.905
# 71630      ZWE       ZW  2023    8.759
#
# [71631 rows x 6 columns]

# %%
print(f'size of the DF : {macro_eco_data_df.shape}')
print('................')
print(macro_eco_data_df.dtypes)
# Out:
# size of the DF : (71631, 6)
# ................
# indicator     object
# country       object
# iso3Code      object
# iso2Code      object
# year          object
# value        float64
# dtype: object

# %%
# change datatype 

macro_eco_data_df = macro_eco_data_df.astype({'year':'int64'})
macro_eco_data_df.dtypes
# Out:
# indicator     object
# country       object
# iso3Code      object
# iso2Code      object
# year           int64
# value        float64
# dtype: object

# %%
macro_eco_data_df = macro_eco_data_df.reset_index()
macro_eco_data_df.head()
# Out:
#    index                                          indicator      country  \
# 0      0  Access to clean fuels and technologies for coo...  Afghanistan
# 1      1  Access to clean fuels and technologies for coo...      Albania
# 2      2  Access to clean fuels and technologies for coo...      Algeria
# 3      3  Access to clean fuels and technologies for coo...      Andorra
# 4      4  Access to clean fuels and technologies for coo...       Angola
#
#   iso3Code iso2Code  year  value
# 0      AFG       AF  2015   27.6
# 1      ALB       AL  2015   76.6
# 2      DZA       DZ  2015   99.6
# 3      AND       AD  2015  100.0
# 4      AGO       AO  2015   47.3

# %%
# export to csv

macro_eco_data_df.to_csv('../Output/macro_economic_data.csv', index=False)

# %% [markdown]
# # (4) Extract Corruption perception indicator
#
#
# source : https://images.transparencycdn.org/images/CPI2023_FullDataSet.zip
#
# from webpage : https://www.transparency.org/en/cpi/2023/media-kit
#
# extract sheet : CPI 2023

# %%
url = "https://images.transparencycdn.org/images/CPI2023_FullDataSet.zip"

# Download the ZIP file (code from Chat GPT)

response = requests.get(url)
if response.status_code == 200:

    # Step 2: Open the ZIP file from memory
    with zipfile.ZipFile(io.BytesIO(response.content), "r") as zip_ref:
        # Extract all files to a folder
        zip_ref.extractall("CPI2023_Data")
        print("Files extracted successfully!")

        # Step 3: Identify the Excel file (assuming there's only one)
        excel_file = [f for f in zip_ref.namelist() if f.endswith(".xlsx")][0]
        excel_path = f"CPI2023_Data/{excel_file}"

        # Step 4: Read the "CPI 2023" sheet into a DataFrame and starting from row 4
        cpi_df = pd.read_excel(excel_path, sheet_name="CPI 2023", skiprows=3)
        print("Sheet 'CPI 2023' loaded into a DataFrame successfully!")

        # Display the first few rows
        cpi_df.head()
else:
    print("Failed to download the file. Check the URL.")
# Out:
# Files extracted successfully!
# Sheet 'CPI 2023' loaded into a DataFrame successfully!

# %%
cpi_df.head()
# Out:
#   Country / Territory ISO3 Region  CPI score 2023  Rank  Standard error  \
# 0             Denmark  DNK  WE/EU              90     1        1.819265
# 1             Finland  FIN  WE/EU              87     2        1.057962
# 2         New Zealand  NZL     AP              85     3        1.916107
# 3              Norway  NOR  WE/EU              84     4        1.380803
# 4           Singapore  SGP     AP              83     5        1.145734
#
#    Number of sources  Lower CI  Upper CI  African Development Bank CPIA  ...  \
# 0                  8  87.01640  92.98360                            NaN  ...
# 1                  8  85.26495  88.73505                            NaN  ...
# 2                  8  81.85758  88.14242                            NaN  ...
# 3                  7  81.73548  86.26452                            NaN  ...
# 4                  9  81.12099  84.87901                            NaN  ...
#
#    Economist Intelligence Unit Country Ratings  \
# 0                                     89.67447
# 1                                     89.67447
# 2                                     89.67447
# 3                                     89.67447
# 4                                     89.67447
#
#    Freedom House Nations in Transit  Global Insights Country Risk Ratings  \
# 0                               NaN                              83.25637
# 1                               NaN                              83.25637
# 2                               NaN                              83.25637
# 3                               NaN                              83.25637
# 4                               NaN                              83.25637
#
#    IMD World Competitiveness Yearbook  PERC Asia Risk Guide  \
# 0                            97.89119                   NaN
# 1                            89.84466                   NaN
# 2                            87.10542                   NaN
# 3                            75.72045                   NaN
# 4                            76.74767              89.29896
#
#    PRS International Country Risk Guide  Varieties of Democracy Project  \
# 0                             100.00000                        78.89152
# 1                              93.38018                        78.16811
# 2                              93.38018                        78.16811
# 3                              84.67139                        78.16811
# 4                              83.27798                        78.16811
#
#    World Bank CPIA  World Economic Forum EOS  \
# 0              NaN                  82.20667
# 1              NaN                  86.76612
# 2              NaN                  70.98344
# 3              NaN                       NaN
# 4              NaN                  88.51975
#
#    World Justice Project Rule of Law Index
# 0                                 87.68097
# 1                                 85.88441
# 2                                 82.29130
# 3                                 86.78268
# 4                                 84.08785
#
# [5 rows x 22 columns]

# %%
cpi_df.columns
# Out:
# Index(['Country / Territory', 'ISO3', 'Region', 'CPI score 2023', 'Rank',
#        'Standard error', 'Number of sources', 'Lower CI', 'Upper CI',
#        'African Development Bank CPIA',
#        'Bertelsmann Foundation Sustainable Governance Index',
#        'Bertelsmann Foundation Transformation Index',
#        'Economist Intelligence Unit Country Ratings',
#        'Freedom House Nations in Transit',
#        'Global Insights Country Risk Ratings',
#        'IMD World Competitiveness Yearbook', 'PERC Asia Risk Guide',
#        'PRS International Country Risk Guide',
#        'Varieties of Democracy Project', 'World Bank CPIA',
#        'World Economic Forum EOS', 'World Justice Project Rule of Law Index'],
#       dtype='object')

# %%
cpi_df = cpi_df.rename(columns={
                                'Country / Territory' : 'country' , 
                                'ISO3' : 'iso3Code' , 
                                'CPI score 2023' : 'CPI_score_2023'
                                
                                })

cpi_df = cpi_df[['country' , 'iso3Code', 'CPI_score_2023']]

cpi_df.columns
# Out:
# Index(['country', 'iso3Code', 'CPI_score_2023'], dtype='object')

# %%
cpi_df.shape
# Out:
# (180, 3)

# %%
cpi_df.head(5)
# Out:
#        country iso3Code  CPI_score_2023
# 0      Denmark      DNK              90
# 1      Finland      FIN              87
# 2  New Zealand      NZL              85
# 3       Norway      NOR              84
# 4    Singapore      SGP              83

# %%
# Save to CSV 
cpi_df.to_csv("../Output/corruption_perception_index.csv", index=False)

# %% [markdown]
# # (5) Extract Global_Peace_Index data
# source Wikidepia : https://en.wikipedia.org/wiki/Global_Peace_Index
#
# the full data and the report is available as PDF from the Economics And Peace organization
# link : https://www.economicsandpeace.org/wp-content/uploads/2023/09/GPI-2023-Web.pdf

# %%
# extract the data from Wikipedia page

## define URL
url = "https://en.wikipedia.org/wiki/Global_Peace_Index"

# Read all tables from the page
tables = pd.read_html(url)

# Find the correct table
gpi_df = tables[1]  

# Display the extracted table
gpi_df = gpi_df.sort_values('Country', ascending=True)
gpi_df.head()
# Out:
#      Rank      Country  Score  Change
# 159   160  Afghanistan  3.294     NaN
# 41     42      Albania  1.809     3.0
# 89     90      Algeria  2.110     2.0
# 71     72       Angola  2.043    19.0
# 46     47    Argentina  1.855     2.0

# %%
# rename column and drop other column
gpi_df = gpi_df.rename(columns={
                                'Country' : 'country',
                                'Score' : 'Global_Peace_Index_2023'
                                
                                })
gpi_df = gpi_df[['country', 'Global_Peace_Index_2023']]


gpi_df.head()
# Out:
#          country  Global_Peace_Index_2023
# 159  Afghanistan                    3.294
# 41       Albania                    1.809
# 89       Algeria                    2.110
# 71        Angola                    2.043
# 46     Argentina                    1.855

# %% [markdown]
# #### for the steps below, refer to 2.1 above

# %%
# to identify the countries names that mismatch between IRCC and World bank

countries_wb = pd.DataFrame(countries_wb_df['country'].unique() , columns=['country'])
countries_gpi = pd.DataFrame(gpi_df['country'].unique(),  columns=['country'])

# Add a source column to indicate the origin
countries_wb['source'] = 'countries_wb'
countries_gpi['source'] = 'countries_gpi'

# Concatenate the two DataFrames
all_countries = pd.concat([countries_wb, countries_gpi], ignore_index=True)

# Find non-corresponding values
non_corresponding_values = all_countries.groupby('country').filter(lambda x: len(x) == 1)

# Display the non-corresponding values with their origin
print(non_corresponding_values)

# to change the countries name, printexport this DF below and work with the resul
# non_corresponding_values.to_csv('Output/non_corresponding_countries.csv')
# Out:
#                  country         source
# 0                  Aruba   countries_wb
# 4                Andorra   countries_wb
# 8         American Samoa   countries_wb
# 9    Antigua and Barbuda   countries_wb
# 20          Bahamas, The   countries_wb
# ..                   ...            ...
# 362           The Gambia  countries_gpi
# 366               Turkey  countries_gpi
# 375            Venezuela  countries_gpi
# 376              Vietnam  countries_gpi
# 377                Yemen  countries_gpi
#
# [96 rows x 2 columns]

# %%
# Change countries name to match to th United Nations standard

gpi_df['country'] = gpi_df['country'].replace({
                            
                                                'Czech Republic' : 'Czechia' ,
                                                'Democratic Republic of the Congo' : 'Congo, Dem. Rep.' ,
                                                'East Timor' : 'Timor-Leste' ,
                                                'Egypt' : 'Egypt, Arab Rep.' ,
                                                'Iran' : 'Iran, Islamic Rep.' ,
                                                'Ivory Coast' : "Cote d'Ivoire" ,
                                                'Kyrgyzstan' : 'Kyrgyz Republic' ,
                                                'Laos' : 'Lao PDR' ,
                                                'North Korea' : "Korea, Dem. People's Rep." ,
                                                'Palestine' : 'West Bank and Gaza' ,
                                                'Republic of the Congo' : 'Congo, Rep.' ,
                                                'Russia' : 'Russian Federation' ,
                                                'Slovakia' : 'Slovak Republic' ,
                                                'South Korea' : 'Korea, Rep.' ,
                                                'Syria' : 'Syrian Arab Republic' ,
                                                'Taiwan' : 'Taiwan' ,
                                                'The Gambia' : 'Gambia, The' ,
                                                'Turkey' : 'Turkiye' ,
                                                'Venezuela' : 'Venezuela, RB' ,
                                                'Vietnam' : 'Viet Nam' ,
                                                'Yemen' : 'Yemen, Rep.' 

                                     })

# %%
# to identify the countries names that mismatch between IRCC and World bank

countries_wb = pd.DataFrame(countries_wb_df['country'].unique() , columns=['country'])
countries_gpi = pd.DataFrame(gpi_df['country'].unique(),  columns=['country'])

# Add a source column to indicate the origin
countries_wb['source'] = 'countries_wb'
countries_gpi['source'] = 'countries_gpi'

# Concatenate the two DataFrames
all_countries = pd.concat([countries_wb, countries_gpi], ignore_index=True)

# Find non-corresponding values
non_corresponding_values = all_countries.groupby('country').filter(lambda x: len(x) == 1)

# Display the non-corresponding values with their origin
print(non_corresponding_values)
# Out:
#                             country         source
# 0                             Aruba   countries_wb
# 4                           Andorra   countries_wb
# 8                    American Samoa   countries_wb
# 9               Antigua and Barbuda   countries_wb
# 20                     Bahamas, The   countries_wb
# 23                           Belize   countries_wb
# 24                          Bermuda   countries_wb
# 27                         Barbados   countries_wb
# 28                Brunei Darussalam   countries_wb
# 34                  Channel Islands   countries_wb
# 42                          Comoros   countries_wb
# 43                       Cabo Verde   countries_wb
# 46                          Curacao   countries_wb
# 47                   Cayman Islands   countries_wb
# 52                         Dominica   countries_wb
# 63                             Fiji   countries_wb
# 65                    Faroe Islands   countries_wb
# 66            Micronesia, Fed. Sts.   countries_wb
# 71                        Gibraltar   countries_wb
# 77                          Grenada   countries_wb
# 78                        Greenland   countries_wb
# 80                             Guam   countries_wb
# 82             Hong Kong SAR, China   countries_wb
# 88                      Isle of Man   countries_wb
# 103                        Kiribati   countries_wb
# 104             St. Kitts and Nevis   countries_wb
# 111                       St. Lucia   countries_wb
# 112                   Liechtenstein   countries_wb
# 116                      Luxembourg   countries_wb
# 118                Macao SAR, China   countries_wb
# 119        St. Martin (French part)   countries_wb
# 121                          Monaco   countries_wb
# 124                        Maldives   countries_wb
# 126                Marshall Islands   countries_wb
# 129                           Malta   countries_wb
# 133        Northern Mariana Islands   countries_wb
# 140                   New Caledonia   countries_wb
# 147                           Nauru   countries_wb
# 154                           Palau   countries_wb
# 157                     Puerto Rico   countries_wb
# 162                French Polynesia   countries_wb
# 171                 Solomon Islands   countries_wb
# 174                      San Marino   countries_wb
# 178           Sao Tome and Principe   countries_wb
# 179                        Suriname   countries_wb
# 184       Sint Maarten (Dutch part)   countries_wb
# 185                      Seychelles   countries_wb
# 187        Turks and Caicos Islands   countries_wb
# 194                           Tonga   countries_wb
# 198                          Tuvalu   countries_wb
# 205  St. Vincent and the Grenadines   countries_wb
# 207          British Virgin Islands   countries_wb
# 208           Virgin Islands (U.S.)   countries_wb
# 210                         Vanuatu   countries_wb
# 211                           Samoa   countries_wb
# 358                          Taiwan  countries_gpi

# %%
gpi_df.shape
# Out:
# (163, 2)

# %%
# Save to CSV 
gpi_df.to_csv("../Output/Global_Peace_Index.csv", index=False)
